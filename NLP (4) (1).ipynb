# %%
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from nltk import FreqDist
from nltk.metrics import jaccard_distance

def sentence_similarity(sentence1, sentence2):
    stop_words = set(stopwords.words('arabic'))
    words1 = [word for word in word_tokenize(sentence1) if word.isalpha() and word not in stop_words]
    words2 = [word for word in word_tokenize(sentence2) if word.isalpha() and word not in stop_words]

    freq_dist1 = FreqDist(words1)
    freq_dist2 = FreqDist(words2)

    return 1 - jaccard_distance(set(freq_dist1), set(freq_dist2))

sentence1 = "مرحبًا، كيف حالك؟"
sentence2 = "مرحبًا، كيف الحال؟"
similarity = sentence_similarity(sentence1, sentence2)
print(f"Similarity: {similarity}")
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# <ipython-input-7-5bdeefc13431> in <cell line: 18>()
#      16 sentence1 = "مرحبًا، كيف حالك؟"
#      17 sentence2 = "مرحبًا، كيف الحال؟"
# ---> 18 similarity = sentence_similarity(sentence1, sentence2)
#      19 print(f"Similarity: {similarity}")
#
# <ipython-input-7-5bdeefc13431> in sentence_similarity(sentence1, sentence2)
#      12     freq_dist2 = FreqDist(words2)
#      13
# ---> 14     return 1 - jaccard_distance(set(freq_dist1), set(freq_dist2))
#      15
#      16 sentence1 = "مرحبًا، كيف حالك؟"
#
# /usr/local/lib/python3.10/dist-packages/nltk/metrics/distance.py in jaccard_distance(label1, label2)
#     217 def jaccard_distance(label1, label2):
#     218     """Distance metric comparing set-similarity."""
# --> 219     return (len(label1.union(label2)) - len(label1.intersection(label2))) / len(
#     220         label1.union(label2)
#     221     )
#
# ZeroDivisionError: division by zero

# %%
import nltk

# %%
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# True

# %%
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# True

# %%
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from nltk import FreqDist
from nltk.metrics import jaccard_distance

def sentence_similarity(sentence1, sentence2):
    stop_words = set(stopwords.words('arabic'))
    words1 = [word for word in word_tokenize(sentence1) if word.isalpha() and word not in stop_words]
    words2 = [word for word in word_tokenize(sentence2) if word.isalpha() and word not in stop_words]

    if not words1 or not words2:
        return 0.0  # Return zero similarity for empty sets

    freq_dist1 = FreqDist(words1)
    freq_dist2 = FreqDist(words2)

    return 1 - jaccard_distance(set(freq_dist1), set(freq_dist2))

sentence1 = "مرحبًا، كيف حالك؟"
sentence2 = "مرحبًا، كيف الحال؟"
similarity = sentence_similarity(sentence1, sentence2)
print(f"Similarity: {similarity}")
# Out:
# Similarity: 0.0

# %%
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from nltk import FreqDist
from nltk.metrics import jaccard_similarity

def sentence_similarity(sentence1, sentence2):
    stop_words = set(stopwords.words('arabic'))
    words1 = [word for word in word_tokenize(sentence1) if word.isalpha() and word not in stop_words]
    words2 = [word for word in word_tokenize(sentence2) if word.isalpha() and word not in stop_words]

    if not words1 or not words2:
        return 0.0  # Return zero similarity for empty sets

    freq_dist1 = FreqDist(words1)
    freq_dist2 = FreqDist(words2)

    return jaccard_similarity(set(freq_dist1), set(freq_dist2))

sentence1 = "مرحبًا، كيف حالك؟"
sentence2 = "مرحبًا، كيف الحال؟"
similarity = sentence_similarity(sentence1, sentence2)
print(f"Similarity: {similarity}")
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-12-0dbe9c3fa37a> in <cell line: 4>()
#       2 from nltk.tokenize import word_tokenize
#       3 from nltk import FreqDist
# ----> 4 from nltk.metrics import jaccard_similarity
#       5
#       6 def sentence_similarity(sentence1, sentence2):
#
# ImportError: cannot import name 'jaccard_similarity' from 'nltk.metrics' (/usr/local/lib/python3.10/dist-packages/nltk/metrics/__init__.py)
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from nltk import FreqDist

def sentence_similarity(sentence1, sentence2):
    stop_words = set(stopwords.words('arabic'))
    words1 = [word for word in word_tokenize(sentence1) if word.isalpha() and word not in stop_words]
    words2 = [word for word in word_tokenize(sentence2) if word.isalpha() and word not in stop_words]

    if not words1 or not words2:
        return 0.0  # Return zero similarity for empty sets

    set1 = set(words1)
    set2 = set(words2)

    intersection = len(set1.intersection(set2))
    union = len(set1.union(set2))

    similarity = intersection / union

    return similarity

sentence1 = "مرحبًا، كيف حالك؟"
sentence2 = "مرحبًا، كيف الحال؟"
similarity = sentence_similarity(sentence1, sentence2)
print(f"Similarity: {similarity}")
# Out:
# Similarity: 0.0

# %%
import nltk
from nltk.corpus import stopwords
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity

nltk.download('stopwords')

def preprocess_text(text):
    stop_words = set(stopwords.words('arabic'))
    words = nltk.word_tokenize(text)
    filtered_words = [word for word in words if word.lower() not in stop_words and word.isalpha()]
    return ' '.join(filtered_words)

def calculate_similarity(sentence1, sentence2):
    preprocessed_sentence1 = preprocess_text(sentence1)
    preprocessed_sentence2 = preprocess_text(sentence2)

    vectorizer = TfidfVectorizer()
    tfidf_matrix = vectorizer.fit_transform([preprocessed_sentence1, preprocessed_sentence2])

    similarity = cosine_similarity(tfidf_matrix[0], tfidf_matrix[1])[0, 0]
    return similarity

# Example usage:
sentence1 = "مرحبا، كيف حالك؟"
sentence2 = "مرحبا، ماأخبارك؟"

similarity_score = calculate_similarity(sentence1, sentence2)
print(f"Similarity between the sentences: {similarity_score}")
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-16-39f1d21f563c> in <cell line: 28>()
#      26 sentence2 = "مرحبا، ماأخبارك؟"
#      27
# ---> 28 similarity_score = calculate_similarity(sentence1, sentence2)
#      29 print(f"Similarity between the sentences: {similarity_score}")
#
# <ipython-input-16-39f1d21f563c> in calculate_similarity(sentence1, sentence2)
#      17
#      18     vectorizer = TfidfVectorizer()
# ---> 19     tfidf_matrix = vectorizer.fit_transform([preprocessed_sentence1, preprocessed_sentence2])
#      20
#      21     similarity = cosine_similarity(tfidf_matrix[0], tfidf_matrix[1])[0, 0]
#
# /usr/local/lib/python3.10/dist-packages/sklearn/feature_extraction/text.py in fit_transform(self, raw_documents, y)
#    2131             sublinear_tf=self.sublinear_tf,
#    2132         )
# -> 2133         X = super().fit_transform(raw_documents)
#    2134         self._tfidf.fit(X)
#    2135         # X is already a transformed view of raw_documents so
#
# /usr/local/lib/python3.10/dist-packages/sklearn/feature_extraction/text.py in fit_transform(self, raw_documents, y)
#    1386                     break
#    1387
# -> 1388         vocabulary, X = self._count_vocab(raw_documents, self.fixed_vocabulary_)
#    1389
#    1390         if self.binary:
#
# /usr/local/lib/python3.10/dist-packages/sklearn/feature_extraction/text.py in _count_vocab(self, raw_documents, fixed_vocab)
#    1292             vocabulary = dict(vocabulary)
#    1293             if not vocabulary:
# -> 1294                 raise ValueError(
#    1295                     "empty vocabulary; perhaps the documents only contain stop words"
#    1296                 )
#
# ValueError: empty vocabulary; perhaps the documents only contain stop words

# %%
import nltk
from nltk.corpus import stopwords
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity

nltk.download('stopwords')

def preprocess_text(text):
    stop_words = set(stopwords.words('arabic'))
    words = nltk.word_tokenize(text)
    filtered_words = [word for word in words if word.lower() not in stop_words and word.isalpha()]
    return ' '.join(filtered_words)

def calculate_similarity(sentence1, sentence2):
    preprocessed_sentence1 = preprocess_text(sentence1)
    preprocessed_sentence2 = preprocess_text(sentence2)

    vectorizer = TfidfVectorizer(min_df=1)  # Adjust min_df as needed
    tfidf_matrix = vectorizer.fit_transform([preprocessed_sentence1, preprocessed_sentence2])

    similarity = cosine_similarity(tfidf_matrix[0], tfidf_matrix[1])[0, 0]
    return similarity

# Example usage:
sentence1 = "مرحبا، كيف حالك؟"
sentence2 = "مرحبا، ماأخبارك؟"

similarity_score = calculate_similarity(sentence1, sentence2)
print(f"Similarity between the sentences: {similarity_score}")
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-17-d72f567fef26> in <cell line: 28>()
#      26 sentence2 = "مرحبا، ماأخبارك؟"
#      27
# ---> 28 similarity_score = calculate_similarity(sentence1, sentence2)
#      29 print(f"Similarity between the sentences: {similarity_score}")
#
# <ipython-input-17-d72f567fef26> in calculate_similarity(sentence1, sentence2)
#      17
#      18     vectorizer = TfidfVectorizer(min_df=1)  # Adjust min_df as needed
# ---> 19     tfidf_matrix = vectorizer.fit_transform([preprocessed_sentence1, preprocessed_sentence2])
#      20
#      21     similarity = cosine_similarity(tfidf_matrix[0], tfidf_matrix[1])[0, 0]
#
# /usr/local/lib/python3.10/dist-packages/sklearn/feature_extraction/text.py in fit_transform(self, raw_documents, y)
#    2131             sublinear_tf=self.sublinear_tf,
#    2132         )
# -> 2133         X = super().fit_transform(raw_documents)
#    2134         self._tfidf.fit(X)
#    2135         # X is already a transformed view of raw_documents so
#
# /usr/local/lib/python3.10/dist-packages/sklearn/feature_extraction/text.py in fit_transform(self, raw_documents, y)
#    1386                     break
#    1387
# -> 1388         vocabulary, X = self._count_vocab(raw_documents, self.fixed_vocabulary_)
#    1389
#    1390         if self.binary:
#
# /usr/local/lib/python3.10/dist-packages/sklearn/feature_extraction/text.py in _count_vocab(self, raw_documents, fixed_vocab)
#    1292             vocabulary = dict(vocabulary)
#    1293             if not vocabulary:
# -> 1294                 raise ValueError(
#    1295                     "empty vocabulary; perhaps the documents only contain stop words"
#    1296                 )
#
# ValueError: empty vocabulary; perhaps the documents only contain stop words

# %%
pip install nltk
# Out:
# Requirement already satisfied: nltk in /usr/local/lib/python3.10/dist-packages (3.8.1)
# Requirement already satisfied: click in /usr/local/lib/python3.10/dist-packages (from nltk) (8.1.7)
# Requirement already satisfied: joblib in /usr/local/lib/python3.10/dist-packages (from nltk) (1.3.2)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.10/dist-packages (from nltk) (2023.6.3)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from nltk) (4.66.1)

# %%
import nltk
from nltk.corpus import stopwords
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity

nltk.download('stopwords')
nltk.download('punkt')

def preprocess_text(text):
    stop_words = set(stopwords.words('arabic'))
    words = nltk.word_tokenize(text)
    filtered_words = [word for word in words if word.lower() not in stop_words and word.isalpha()]
    return ' '.join(filtered_words)

def calculate_similarity(sentence1, sentence2):
    preprocessed_sentence1 = preprocess_text(sentence1)
    preprocessed_sentence2 = preprocess_text(sentence2)

    vectorizer = TfidfVectorizer(min_df=1, analyzer='word')  # Adjust min_df as needed
    tfidf_matrix = vectorizer.fit_transform([preprocessed_sentence1, preprocessed_sentence2])

    similarity = cosine_similarity(tfidf_matrix[0], tfidf_matrix[1])[0, 0]
    return similarity

# Example usage:
sentence1 = "مرحبا، كيف حالك؟"
sentence2 = "مرحبا، كيف يمكنني مساعدتك؟"

similarity_score = calculate_similarity(sentence1, sentence2)
print(f"Similarity between the sentences: {similarity_score}")
# Out:
# Similarity between the sentences: 0.0
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
pip install sentence_transformers
# Out:
# Collecting sentence_transformers
#   Downloading sentence-transformers-2.2.2.tar.gz (85 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.0/86.0 kB 765.3 kB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting transformers<5.0.0,>=4.6.0 (from sentence_transformers)
#   Downloading transformers-4.35.2-py3-none-any.whl (7.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.9/7.9 MB 36.1 MB/s eta 0:00:00
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from sentence_transformers) (4.66.1)
# Requirement already satisfied: torch>=1.6.0 in /usr/local/lib/python3.10/dist-packages (from sentence_transformers) (2.1.0+cu118)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.10/dist-packages (from sentence_transformers) (0.16.0+cu118)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from sentence_transformers) (1.23.5)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.10/dist-packages (from sentence_transformers) (1.2.2)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from sentence_transformers) (1.11.3)
# Requirement already satisfied: nltk in /usr/local/lib/python3.10/dist-packages (from sentence_transformers) (3.8.1)
# Collecting sentencepiece (from sentence_transformers)
#   Downloading sentencepiece-0.1.99-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 46.8 MB/s eta 0:00:00
# Collecting huggingface-hub>=0.4.0 (from sentence_transformers)
#   Downloading huggingface_hub-0.19.3-py3-none-any.whl (311 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 311.2/311.2 kB 24.3 MB/s eta 0:00:00
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.4.0->sentence_transformers) (3.13.1)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.4.0->sentence_transformers) (2023.6.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.4.0->sentence_transformers) (2.31.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.4.0->sentence_transformers) (6.0.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.4.0->sentence_transformers) (4.5.0)
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.4.0->sentence_transformers) (23.2)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=1.6.0->sentence_transformers) (1.12)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.6.0->sentence_transformers) (3.2.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.6.0->sentence_transformers) (3.1.2)
# Requirement already satisfied: triton==2.1.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.6.0->sentence_transformers) (2.1.0)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers<5.0.0,>=4.6.0->sentence_transformers) (2023.6.3)
# Collecting tokenizers<0.19,>=0.14 (from transformers<5.0.0,>=4.6.0->sentence_transformers)
#   Downloading tokenizers-0.15.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.8/3.8 MB 71.6 MB/s eta 0:00:00
# Collecting safetensors>=0.3.1 (from transformers<5.0.0,>=4.6.0->sentence_transformers)
#   Downloading safetensors-0.4.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 63.8 MB/s eta 0:00:00
# Requirement already satisfied: click in /usr/local/lib/python3.10/dist-packages (from nltk->sentence_transformers) (8.1.7)
# Requirement already satisfied: joblib in /usr/local/lib/python3.10/dist-packages (from nltk->sentence_transformers) (1.3.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->sentence_transformers) (3.2.0)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /usr/local/lib/python3.10/dist-packages (from torchvision->sentence_transformers) (9.4.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.6.0->sentence_transformers) (2.1.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.4.0->sentence_transformers) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.4.0->sentence_transformers) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.4.0->sentence_transformers) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.4.0->sentence_transformers) (2023.7.22)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=1.6.0->sentence_transformers) (1.3.0)
# Building wheels for collected packages: sentence_transformers
#   Building wheel for sentence_transformers (setup.py) ... done
#   Created wheel for sentence_transformers: filename=sentence_transformers-2.2.2-py3-none-any.whl size=125923 sha256=610d01b9c1a454375a0a8c04a9b7813b7494736c0403ce2396d75b62106366fa
#   Stored in directory: /root/.cache/pip/wheels/62/f2/10/1e606fd5f02395388f74e7462910fe851042f97238cbbd902f
# Successfully built sentence_transformers
# Installing collected packages: sentencepiece, safetensors, huggingface-hub, tokenizers, transformers, sentence_transformers
# Successfully installed huggingface-hub-0.19.3 safetensors-0.4.0 sentence_transformers-2.2.2 sentencepiece-0.1.99 tokenizers-0.15.0 transformers-4.35.2

# %%
from sentence_transformers import SentenceTransformer, util

# Load a pre-trained BERT model
model = SentenceTransformer('bert-base-nli-mean-tokens')

# Encode sentences
sentence1 = "مرحباً, كيف حالك؟"
sentence2 = "أهلاً, ما أخبارك؟"
embeddings1 = model.encode(sentence1, convert_to_tensor=True)
embeddings2 = model.encode(sentence2, convert_to_tensor=True)

# Calculate cosine similarity
cosine_similarity = util.pytorch_cos_sim(embeddings1, embeddings2)
print(f"Cosine Similarity: {cosine_similarity.item()}")
# Out:
# Cosine Similarity: 0.9289291501045227

# %%
# Encode sentences
sentence1 = "الطفل مسرور جداً"
sentence2 = "الطفل شديد السعادة"
embeddings1 = model.encode(sentence1, convert_to_tensor=True)
embeddings2 = model.encode(sentence2, convert_to_tensor=True)

# Calculate cosine similarity
cosine_similarity = util.pytorch_cos_sim(embeddings1, embeddings2)
print(f"Cosine Similarity: {cosine_similarity.item()}")
# Out:
# Cosine Similarity: 0.9230090379714966

# %%
# Encode sentences
sentence1 = "الطفل مسرور جداً"
sentence2 = "الولد مكتئب"
embeddings1 = model.encode(sentence1, convert_to_tensor=True)
embeddings2 = model.encode(sentence2, convert_to_tensor=True)

# Calculate cosine similarity
cosine_similarity = util.pytorch_cos_sim(embeddings1, embeddings2)
print(f"Cosine Similarity: {cosine_similarity.item()}")
# Out:
# Cosine Similarity: 0.9279042482376099

# %%
from sentence_transformers import SentenceTransformer, util
from transformers import AutoTokenizer

# Load a pre-trained Arabic BERT model
model_name = 'aubmindlab/bert-base-arabertv01'
model = SentenceTransformer(model_name)

# Load the corresponding tokenizer
tokenizer = AutoTokenizer.from_pretrained(model_name)

# Encode Arabic sentences
sentence1 = "الطفل مسرور جداً"
sentence2 = "الطفل شديد السعادة"
tokens1 = tokenizer(sentence1, return_tensors='pt')
tokens2 = tokenizer(sentence2, return_tensors='pt')
embeddings1 = model.encode(**tokens1, convert_to_tensor=True)
embeddings2 = model.encode(**tokens2, convert_to_tensor=True)

# Calculate cosine similarity
cosine_similarity = util.pytorch_cos_sim(embeddings1, embeddings2)
print(f"Cosine Similarity: {cosine_similarity.item()}")
# Out:
# (…)0f79498f26f47dfc6207b56ea/.gitattributes:   0%|          | 0.00/445 [00:00<?, ?B/s]
# (…)7afcd0f79498f26f47dfc6207b56ea/README.md:   0%|          | 0.00/8.37k [00:00<?, ?B/s]
# (…)fcd0f79498f26f47dfc6207b56ea/config.json:   0%|          | 0.00/576 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/543M [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/543M [00:00<?, ?B/s]
# (…)6f47dfc6207b56ea/special_tokens_map.json:   0%|          | 0.00/112 [00:00<?, ?B/s]
# (…)0f79498f26f47dfc6207b56ea/tokenizer.json:   0%|          | 0.00/2.70M [00:00<?, ?B/s]
# (…)f26f47dfc6207b56ea/tokenizer_config.json:   0%|          | 0.00/379 [00:00<?, ?B/s]
# (…)7afcd0f79498f26f47dfc6207b56ea/vocab.txt:   0%|          | 0.00/780k [00:00<?, ?B/s]
# WARNING:sentence_transformers.SentenceTransformer:No sentence-transformers model found with name /root/.cache/torch/sentence_transformers/aubmindlab_bert-base-arabertv01. Creating a new one with MEAN pooling.
# (…)rtv01/resolve/main/tokenizer_config.json:   0%|          | 0.00/379 [00:00<?, ?B/s]
# (…)base-arabertv01/resolve/main/config.json:   0%|          | 0.00/576 [00:00<?, ?B/s]
# (…)t-base-arabertv01/resolve/main/vocab.txt:   0%|          | 0.00/780k [00:00<?, ?B/s]
# (…)e-arabertv01/resolve/main/tokenizer.json:   0%|          | 0.00/2.70M [00:00<?, ?B/s]
# (…)v01/resolve/main/special_tokens_map.json:   0%|          | 0.00/112 [00:00<?, ?B/s]
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-27-c25e4fe5f186> in <cell line: 16>()
#      14 tokens1 = tokenizer(sentence1, return_tensors='pt')
#      15 tokens2 = tokenizer(sentence2, return_tensors='pt')
# ---> 16 embeddings1 = model.encode(**tokens1, convert_to_tensor=True)
#      17 embeddings2 = model.encode(**tokens2, convert_to_tensor=True)
#      18
#
# TypeError: SentenceTransformer.encode() got an unexpected keyword argument 'input_ids'

# %%
pip install sentence_transformers transformers
# Out:
# Requirement already satisfied: sentence_transformers in /usr/local/lib/python3.10/dist-packages (2.2.2)
# Requirement already satisfied: transformers in /usr/local/lib/python3.10/dist-packages (4.35.2)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from sentence_transformers) (4.66.1)
# Requirement already satisfied: torch>=1.6.0 in /usr/local/lib/python3.10/dist-packages (from sentence_transformers) (2.1.0+cu118)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.10/dist-packages (from sentence_transformers) (0.16.0+cu118)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from sentence_transformers) (1.23.5)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.10/dist-packages (from sentence_transformers) (1.2.2)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from sentence_transformers) (1.11.3)
# Requirement already satisfied: nltk in /usr/local/lib/python3.10/dist-packages (from sentence_transformers) (3.8.1)
# Requirement already satisfied: sentencepiece in /usr/local/lib/python3.10/dist-packages (from sentence_transformers) (0.1.99)
# Requirement already satisfied: huggingface-hub>=0.4.0 in /usr/local/lib/python3.10/dist-packages (from sentence_transformers) (0.19.3)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from transformers) (3.13.1)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from transformers) (23.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (6.0.1)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (2023.6.3)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from transformers) (2.31.0)
# Requirement already satisfied: tokenizers<0.19,>=0.14 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.15.0)
# Requirement already satisfied: safetensors>=0.3.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.4.0)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.4.0->sentence_transformers) (2023.6.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.4.0->sentence_transformers) (4.5.0)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=1.6.0->sentence_transformers) (1.12)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.6.0->sentence_transformers) (3.2.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.6.0->sentence_transformers) (3.1.2)
# Requirement already satisfied: triton==2.1.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.6.0->sentence_transformers) (2.1.0)
# Requirement already satisfied: click in /usr/local/lib/python3.10/dist-packages (from nltk->sentence_transformers) (8.1.7)
# Requirement already satisfied: joblib in /usr/local/lib/python3.10/dist-packages (from nltk->sentence_transformers) (1.3.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2023.7.22)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->sentence_transformers) (3.2.0)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /usr/local/lib/python3.10/dist-packages (from torchvision->sentence_transformers) (9.4.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.6.0->sentence_transformers) (2.1.3)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=1.6.0->sentence_transformers) (1.3.0)

# %%
from sentence_transformers import SentenceTransformer, util
from transformers import AutoTokenizer

# Load a pre-trained Arabic BERT model
model_name = 'aubmindlab/bert-base-arabertv01'
model = SentenceTransformer(model_name)

# Load the corresponding tokenizer
tokenizer = AutoTokenizer.from_pretrained(model_name)

# Encode Arabic sentences
sentence1 = "الطفل مسرور جداً"
sentence2 = "الطفل شديد السعادة"
tokens1 = tokenizer.encode_plus(sentence1, return_tensors='pt', padding=True, truncation=True)
tokens2 = tokenizer.encode_plus(sentence2, return_tensors='pt', padding=True, truncation=True)
embeddings1 = model.encode(tokens1['input_ids'], convert_to_tensor=True)
embeddings2 = model.encode(tokens2['input_ids'], convert_to_tensor=True)

# Calculate cosine similarity
cosine_similarity = util.pytorch_cos_sim(embeddings1, embeddings2)
print(f"Cosine Similarity: {cosine_similarity.item()}")
# Out:
# WARNING:sentence_transformers.SentenceTransformer:No sentence-transformers model found with name /root/.cache/torch/sentence_transformers/aubmindlab_bert-base-arabertv01. Creating a new one with MEAN pooling.
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-29-cb84a2958bc8> in <cell line: 16>()
#      14 tokens1 = tokenizer.encode_plus(sentence1, return_tensors='pt', padding=True, truncation=True)
#      15 tokens2 = tokenizer.encode_plus(sentence2, return_tensors='pt', padding=True, truncation=True)
# ---> 16 embeddings1 = model.encode(tokens1['input_ids'], convert_to_tensor=True)
#      17 embeddings2 = model.encode(tokens2['input_ids'], convert_to_tensor=True)
#      18
#
# /usr/local/lib/python3.10/dist-packages/sentence_transformers/SentenceTransformer.py in encode(self, sentences, batch_size, show_progress_bar, output_value, convert_to_numpy, convert_to_tensor, device, normalize_embeddings)
#     154
#     155         all_embeddings = []
# --> 156         length_sorted_idx = np.argsort([-self._text_length(sen) for sen in sentences])
#     157         sentences_sorted = [sentences[idx] for idx in length_sorted_idx]
#     158
#
# /usr/local/lib/python3.10/dist-packages/sentence_transformers/SentenceTransformer.py in <listcomp>(.0)
#     154
#     155         all_embeddings = []
# --> 156         length_sorted_idx = np.argsort([-self._text_length(sen) for sen in sentences])
#     157         sentences_sorted = [sentences[idx] for idx in length_sorted_idx]
#     158
#
# /usr/local/lib/python3.10/dist-packages/sentence_transformers/SentenceTransformer.py in _text_length(self, text)
#     569             return len(text)
#     570         else:
# --> 571             return sum([len(t) for t in text])      #Sum of length of individual strings
#     572
#     573     def fit(self,
#
# /usr/local/lib/python3.10/dist-packages/sentence_transformers/SentenceTransformer.py in <listcomp>(.0)
#     569             return len(text)
#     570         else:
# --> 571             return sum([len(t) for t in text])      #Sum of length of individual strings
#     572
#     573     def fit(self,
#
# /usr/local/lib/python3.10/dist-packages/torch/_tensor.py in __len__(self)
#     966             return handle_torch_function(Tensor.__len__, (self,), self)
#     967         if self.dim() == 0:
# --> 968             raise TypeError("len() of a 0-d tensor")
#     969         if torch._C._get_tracing_state():
#     970             warnings.warn(
#
# TypeError: len() of a 0-d tensor

# %%
from sentence_transformers import SentenceTransformer, util
from transformers import AutoTokenizer
import torch

# Load a pre-trained Arabic BERT model
model_name = 'aubmindlab/bert-base-arabertv01'
model = SentenceTransformer(model_name)

# Load the corresponding tokenizer
tokenizer = AutoTokenizer.from_pretrained(model_name)

# Encode Arabic sentences
sentence1 = "الطفل مسرور جداً"
sentence2 = "الطفل شديد السعادة"
tokens1 = tokenizer.encode_plus(sentence1, return_tensors='pt', padding=True, truncation=True)
tokens2 = tokenizer.encode_plus(sentence2, return_tensors='pt', padding=True, truncation=True)
input_ids1 = tokens1['input_ids']
input_ids2 = tokens2['input_ids']

# Add batch dimension to the input tensors
input_ids1 = torch.unsqueeze(input_ids1, dim=0)
input_ids2 = torch.unsqueeze(input_ids2, dim=0)

# Encode the sentences
embeddings1 = model.encode(input_ids1, convert_to_tensor=True)
embeddings2 = model.encode(input_ids2, convert_to_tensor=True)

# Calculate cosine similarity
cosine_similarity = util.pytorch_cos_sim(embeddings1, embeddings2)
print(f"Cosine Similarity: {cosine_similarity.item()}")
# Out:
# WARNING:sentence_transformers.SentenceTransformer:No sentence-transformers model found with name /root/.cache/torch/sentence_transformers/aubmindlab_bert-base-arabertv01. Creating a new one with MEAN pooling.
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-30-860367071b3a> in <cell line: 25>()
#      23
#      24 # Encode the sentences
# ---> 25 embeddings1 = model.encode(input_ids1, convert_to_tensor=True)
#      26 embeddings2 = model.encode(input_ids2, convert_to_tensor=True)
#      27
#
# /usr/local/lib/python3.10/dist-packages/sentence_transformers/SentenceTransformer.py in encode(self, sentences, batch_size, show_progress_bar, output_value, convert_to_numpy, convert_to_tensor, device, normalize_embeddings)
#     159         for start_index in trange(0, len(sentences), batch_size, desc="Batches", disable=not show_progress_bar):
#     160             sentences_batch = sentences_sorted[start_index:start_index+batch_size]
# --> 161             features = self.tokenize(sentences_batch)
#     162             features = batch_to_device(features, device)
#     163
#
# /usr/local/lib/python3.10/dist-packages/sentence_transformers/SentenceTransformer.py in tokenize(self, texts)
#     317         Tokenizes the texts
#     318         """
# --> 319         return self._first_module().tokenize(texts)
#     320
#     321     def get_sentence_features(self, *features):
#
# /usr/local/lib/python3.10/dist-packages/sentence_transformers/models/Transformer.py in tokenize(self, texts)
#     101             for text_tuple in texts:
#     102                 batch1.append(text_tuple[0])
# --> 103                 batch2.append(text_tuple[1])
#     104             to_tokenize = [batch1, batch2]
#     105
#
# IndexError: index 1 is out of bounds for dimension 0 with size 1

# %%
from sentence_transformers import SentenceTransformer, util
from transformers import AutoTokenizer
import torch

# Load a pre-trained Arabic BERT model
model_name = 'aubmindlab/bert-base-arabertv01'
model = SentenceTransformer(model_name)

# Load the corresponding tokenizer
tokenizer = AutoTokenizer.from_pretrained(model_name)

# Encode Arabic sentences
sentence1 = "الطفل مسرور جداً"
sentence2 = "الطفل شديد السعادة"
sentences = [sentence1, sentence2]
tokens = tokenizer.batch_encode_plus(sentences, return_tensors='pt', padding=True, truncation=True)
input_ids = tokens['input_ids']

# Encode the sentences
embeddings = model.encode(input_ids, convert_to_tensor=True)

# Calculate cosine similarity
cosine_similarity = util.pytorch_cos_sim(embeddings[0], embeddings[1])
print(f"Cosine Similarity: {cosine_similarity.item()}")
# Out:
# WARNING:sentence_transformers.SentenceTransformer:No sentence-transformers model found with name /root/.cache/torch/sentence_transformers/aubmindlab_bert-base-arabertv01. Creating a new one with MEAN pooling.
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-31-493c7fa9a5d8> in <cell line: 20>()
#      18
#      19 # Encode the sentences
# ---> 20 embeddings = model.encode(input_ids, convert_to_tensor=True)
#      21
#      22 # Calculate cosine similarity
#
# /usr/local/lib/python3.10/dist-packages/sentence_transformers/SentenceTransformer.py in encode(self, sentences, batch_size, show_progress_bar, output_value, convert_to_numpy, convert_to_tensor, device, normalize_embeddings)
#     154
#     155         all_embeddings = []
# --> 156         length_sorted_idx = np.argsort([-self._text_length(sen) for sen in sentences])
#     157         sentences_sorted = [sentences[idx] for idx in length_sorted_idx]
#     158
#
# /usr/local/lib/python3.10/dist-packages/sentence_transformers/SentenceTransformer.py in <listcomp>(.0)
#     154
#     155         all_embeddings = []
# --> 156         length_sorted_idx = np.argsort([-self._text_length(sen) for sen in sentences])
#     157         sentences_sorted = [sentences[idx] for idx in length_sorted_idx]
#     158
#
# /usr/local/lib/python3.10/dist-packages/sentence_transformers/SentenceTransformer.py in _text_length(self, text)
#     569             return len(text)
#     570         else:
# --> 571             return sum([len(t) for t in text])      #Sum of length of individual strings
#     572
#     573     def fit(self,
#
# /usr/local/lib/python3.10/dist-packages/sentence_transformers/SentenceTransformer.py in <listcomp>(.0)
#     569             return len(text)
#     570         else:
# --> 571             return sum([len(t) for t in text])      #Sum of length of individual strings
#     572
#     573     def fit(self,
#
# /usr/local/lib/python3.10/dist-packages/torch/_tensor.py in __len__(self)
#     966             return handle_torch_function(Tensor.__len__, (self,), self)
#     967         if self.dim() == 0:
# --> 968             raise TypeError("len() of a 0-d tensor")
#     969         if torch._C._get_tracing_state():
#     970             warnings.warn(
#
# TypeError: len() of a 0-d tensor

# %%
import spacy

# Load the spaCy model
nlp = spacy.load("en_core_web_md")

def sentence_similarity(sentence1, sentence2):
    # Process the sentences with spaCy
    doc1 = nlp(sentence1)
    doc2 = nlp(sentence2)

    # Compute the similarity between the two sentences
    similarity = doc1.similarity(doc2)

    return similarity

# Example usage
sentence1 = "الطفل مسرور جداً"
sentence2 = "الطفل شديد السعادة"
similarity_score = sentence_similarity(sentence1, sentence2)

print(f"Similarity between the sentences: {similarity_score}")
# Out:
# Similarity between the sentences: 0.0
# <ipython-input-38-8cee1038b053>:12: UserWarning: [W008] Evaluating Doc.similarity based on empty vectors.
#   similarity = doc1.similarity(doc2)

# %%
# !python -m spacy download en_core_web_md
# Out:
# 2023-11-15 22:18:05.674660: E tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:9342] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2023-11-15 22:18:05.688952: E tensorflow/compiler/xla/stream_executor/cuda/cuda_fft.cc:609] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2023-11-15 22:18:05.694598: E tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:1518] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2023-11-15 22:18:07.955278: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
#
# ✘ No compatible package found for 'ar_core_web_md' (spaCy v3.6.1)

# %%
python -m spacy download ar_core_news_sm
# Out:
#   File "<ipython-input-40-7b7b85b0d444>", line 1
#     python -m spacy download ar_core_news_sm
#               ^
# SyntaxError: invalid syntax

# %%
python spacy download ar_core_news_sm
# Out:
#   File "<ipython-input-42-0e3cf458f34c>", line 1
#     python spacy download ar_core_news_sm
#            ^
# SyntaxError: invalid syntax

# %%
import spacy

# Load the spaCy Arabic model
nlp_arabic = spacy.load("ar_core_news_sm")

def sentence_similarity_arabic(sentence1, sentence2):
    # Process the Arabic sentences with spaCy
    doc1 = nlp_arabic(sentence1)
    doc2 = nlp_arabic(sentence2)

    # Compute the similarity between the two sentences
    similarity = doc1.similarity(doc2)

    return similarity

# Example usage
sentence1_arabic = "القطة على السجادة."
sentence2_arabic = "القطة تجلس على السجادة."
similarity_score_arabic = sentence_similarity_arabic(sentence1_arabic, sentence2_arabic)

print(f"Similarity between the Arabic sentences: {similarity_score_arabic}")
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-43-e2e9a780eb9c> in <cell line: 4>()
#       2
#       3 # Load the spaCy Arabic model
# ----> 4 nlp_arabic = spacy.load("ar_core_news_sm")
#       5
#       6 def sentence_similarity_arabic(sentence1, sentence2):
#
# /usr/local/lib/python3.10/dist-packages/spacy/__init__.py in load(name, vocab, disable, enable, exclude, config)
#      49     RETURNS (Language): The loaded nlp object.
#      50     """
# ---> 51     return util.load_model(
#      52         name,
#      53         vocab=vocab,
#
# /usr/local/lib/python3.10/dist-packages/spacy/util.py in load_model(name, vocab, disable, enable, exclude, config)
#     470     if name in OLD_MODEL_SHORTCUTS:
#     471         raise IOError(Errors.E941.format(name=name, full=OLD_MODEL_SHORTCUTS[name]))  # type: ignore[index]
# --> 472     raise IOError(Errors.E050.format(name=name))
#     473
#     474
#
# OSError: [E050] Can't find model 'ar_core_news_sm'. It doesn't seem to be a Python package or a valid path to a data directory.

# %%
import ar_core_news_sm

nlp = ar_core_news_sm.load()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-45-ece46a1976eb> in <cell line: 1>()
# ----> 1 import ar_core_news_sm
#       2
#       3 nlp = ar_core_news_sm.load()
#
# ModuleNotFoundError: No module named 'ar_core_news_sm'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
import spacy

# Load the spaCy Arabic model
nlp_arabic = spacy.load("ar_core_news_sm")

def sentence_similarity_arabic(sentence1, sentence2):
    # Process the Arabic sentences with spaCy
    doc1 = nlp_arabic(sentence1)
    doc2 = nlp_arabic(sentence2)

    # Compute the similarity between the two sentences
    similarity = doc1.similarity(doc2)

    return similarity

# Example usage
sentence1_arabic = "القطة على السجادة."
sentence2_arabic = "القطة تجلس على السجادة."
similarity_score_arabic = sentence_similarity_arabic(sentence1_arabic, sentence2_arabic)

print(f"Similarity between the Arabic sentences: {similarity_score_arabic}")

# %%
pip install spacy
# Out:
# Requirement already satisfied: spacy in /usr/local/lib/python3.10/dist-packages (3.6.1)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in /usr/local/lib/python3.10/dist-packages (from spacy) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from spacy) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.10/dist-packages (from spacy) (1.0.10)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.10/dist-packages (from spacy) (2.0.8)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /usr/local/lib/python3.10/dist-packages (from spacy) (3.0.9)
# Requirement already satisfied: thinc<8.2.0,>=8.1.8 in /usr/local/lib/python3.10/dist-packages (from spacy) (8.1.12)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in /usr/local/lib/python3.10/dist-packages (from spacy) (1.1.2)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /usr/local/lib/python3.10/dist-packages (from spacy) (2.4.8)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /usr/local/lib/python3.10/dist-packages (from spacy) (2.0.10)
# Requirement already satisfied: typer<0.10.0,>=0.3.0 in /usr/local/lib/python3.10/dist-packages (from spacy) (0.9.0)
# Requirement already satisfied: pathy>=0.10.0 in /usr/local/lib/python3.10/dist-packages (from spacy) (0.10.3)
# Requirement already satisfied: smart-open<7.0.0,>=5.2.1 in /usr/local/lib/python3.10/dist-packages (from spacy) (6.4.0)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /usr/local/lib/python3.10/dist-packages (from spacy) (4.66.1)
# Requirement already satisfied: numpy>=1.15.0 in /usr/local/lib/python3.10/dist-packages (from spacy) (1.23.5)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from spacy) (2.31.0)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 in /usr/local/lib/python3.10/dist-packages (from spacy) (1.10.13)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from spacy) (3.1.2)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from spacy) (67.7.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from spacy) (23.2)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /usr/local/lib/python3.10/dist-packages (from spacy) (3.3.0)
# Requirement already satisfied: typing-extensions>=4.2.0 in /usr/local/lib/python3.10/dist-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (4.5.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy) (2023.7.22)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in /usr/local/lib/python3.10/dist-packages (from thinc<8.2.0,>=8.1.8->spacy) (0.7.11)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in /usr/local/lib/python3.10/dist-packages (from thinc<8.2.0,>=8.1.8->spacy) (0.1.3)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in /usr/local/lib/python3.10/dist-packages (from typer<0.10.0,>=0.3.0->spacy) (8.1.7)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->spacy) (2.1.3)

# %%
pip install sumy
# Out:
# Collecting sumy
#   Downloading sumy-0.11.0-py2.py3-none-any.whl (97 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 97.3/97.3 kB 3.0 MB/s eta 0:00:00
# Collecting docopt<0.7,>=0.6.1 (from sumy)
#   Downloading docopt-0.6.2.tar.gz (25 kB)
#   Preparing metadata (setup.py) ... done
# Collecting breadability>=0.1.20 (from sumy)
#   Downloading breadability-0.1.20.tar.gz (32 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: requests>=2.7.0 in /usr/local/lib/python3.10/dist-packages (from sumy) (2.31.0)
# Collecting pycountry>=18.2.23 (from sumy)
#   Downloading pycountry-22.3.5.tar.gz (10.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.1/10.1 MB 30.0 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: nltk>=3.0.2 in /usr/local/lib/python3.10/dist-packages (from sumy) (3.8.1)
# Requirement already satisfied: chardet in /usr/local/lib/python3.10/dist-packages (from breadability>=0.1.20->sumy) (5.2.0)
# Requirement already satisfied: lxml>=2.0 in /usr/local/lib/python3.10/dist-packages (from breadability>=0.1.20->sumy) (4.9.3)
# Requirement already satisfied: click in /usr/local/lib/python3.10/dist-packages (from nltk>=3.0.2->sumy) (8.1.7)
# Requirement already satisfied: joblib in /usr/local/lib/python3.10/dist-packages (from nltk>=3.0.2->sumy) (1.3.2)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.10/dist-packages (from nltk>=3.0.2->sumy) (2023.6.3)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from nltk>=3.0.2->sumy) (4.66.1)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from pycountry>=18.2.23->sumy) (67.7.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.7.0->sumy) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.7.0->sumy) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.7.0->sumy) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.7.0->sumy) (2023.7.22)
# Building wheels for collected packages: breadability, docopt, pycountry
#   Building wheel for breadability (setup.py) ... done
#   Created wheel for breadability: filename=breadability-0.1.20-py2.py3-none-any.whl size=21692 sha256=b5f99b986929e9b029e2e9214b23e2dde6e66d20d2a610d3b9267e8c0fc7ae3d
#   Stored in directory: /root/.cache/pip/wheels/64/22/90/b84fcc30e16598db20a0d41340616dbf9b1e82bbcc627b0b33
#   Building wheel for docopt (setup.py) ... done
#   Created wheel for docopt: filename=docopt-0.6.2-py2.py3-none-any.whl size=13706 sha256=9811358b31464439026d16782366e1c4abbe41593ba661fc65bea6def52ca933
#   Stored in directory: /root/.cache/pip/wheels/fc/ab/d4/5da2067ac95b36618c629a5f93f809425700506f72c9732fac
#   Building wheel for pycountry (pyproject.toml) ... done
#   Created wheel for pycountry: filename=pycountry-22.3.5-py2.py3-none-any.whl size=10681832 sha256=9e2887582802ceace5c290bcdb4dc43882f2f495df22c679c7924b2e83f78666
#   Stored in directory: /root/.cache/pip/wheels/03/57/cc/290c5252ec97a6d78d36479a3c5e5ecc76318afcb241ad9dbe
# Successfully built breadability docopt pycountry
# Installing collected packages: docopt, pycountry, breadability, sumy
# Successfully installed breadability-0.1.20 docopt-0.6.2 pycountry-22.3.5 sumy-0.11.0

# %%
import nltk
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# True

# %%
pip install pyarabic
# Out:
# Collecting pyarabic
#   Downloading PyArabic-0.6.15-py3-none-any.whl (126 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 126.4/126.4 kB 2.0 MB/s eta 0:00:00
# Requirement already satisfied: six>=1.14.0 in /usr/local/lib/python3.10/dist-packages (from pyarabic) (1.16.0)
# Installing collected packages: pyarabic
# Successfully installed pyarabic-0.6.15

# %%
from sumy.parsers.plaintext import PlaintextParser
from sumy.nlp.tokenizers import Tokenizer
from sumy.summarizers.lsa import LsaSummarizer

def summarize_arabic_text(text, sentences_count=5):
    # Specify the language
    language = "ar"

    # Parse the text
    parser = PlaintextParser.from_string(text, Tokenizer(language))

    # Initialize the summarizer
    summarizer = LsaSummarizer()

    # Get the summary
    summary = summarizer(parser.document, sentences_count)

    # Print the summary
    for sentence in summary:
        print(sentence)

# Example usage:
arabic_text = "ما هي أفضل مكتبة لكي أستطيع تلخيص أي جملة مكتوبة باللغة العربية بشرط أن تكون تلك المكتبة التي أستخدمها ذات دقة عالية في التعرف على كل أنواع النصوص"
summarize_arabic_text(arabic_text)
# Out:
# ما هي أفضل مكتبة لكي أستطيع تلخيص أي جملة مكتوبة باللغة العربية بشرط أن تكون تلك المكتبة التي أستخدمها ذات دقة عالية في التعرف على كل أنواع النصوص

# %%
from sumy.parsers.plaintext import PlaintextParser
from sumy.nlp.tokenizers import Tokenizer
from sumy.summarizers.lsa import LsaSummarizer

def summarize_arabic_text(text, sentences_count=2):
    language = "ar"
    parser = PlaintextParser.from_string(text, Tokenizer(language))
    summarizer = LsaSummarizer()
    summary = summarizer(parser.document, sentences_count)

    # Collect the summarized sentences into a string
    summarized_text = " ".join(str(sentence) for sentence in summary)

    return summarized_text

# Summarize the Arabic text
arabic_text = """
تقع القاهرة في شمال مصر وهي عاصمتها وأكبر مدينة في البلاد. تعتبر القاهرة مركزًا حضريًا حديثًا يجمع بين التاريخ العريق والحياة الحديثة. تشتهر بمعالمها التاريخية مثل هرم الجيزة والمتحف المصري، حيث يعرض العديد من الآثار الفرعونية. بالإضافة إلى ذلك، تحتوي القاهرة على أسواق نابضة بالحياة ومطاعم تقدم المأكولات اللذيذة.
"""

summarized_text = summarize_arabic_text(arabic_text)
print("Original Text:\n", arabic_text)
print("\nSummarized Text:\n", summarized_text)
# Out:
# Original Text:
#
# تقع القاهرة في شمال مصر وهي عاصمتها وأكبر مدينة في البلاد. تعتبر القاهرة مركزًا حضريًا حديثًا يجمع بين التاريخ العريق والحياة الحديثة. تشتهر بمعالمها التاريخية مثل هرم الجيزة والمتحف المصري، حيث يعرض العديد من الآثار الفرعونية. بالإضافة إلى ذلك، تحتوي القاهرة على أسواق نابضة بالحياة ومطاعم تقدم المأكولات اللذيذة.
#
#
# Summarized Text:
#  تشتهر بمعالمها التاريخية مثل هرم الجيزة والمتحف المصري، تحتوي القاهرة على أسواق نابضة بالحياة ومطاعم تقدم المأكولات اللذيذة.

# %%
arabic_text = """
الطبيعة تمتلك جمالًا لا يضاهى. في قلب الغابة الكثيفة، تنمو الأزهار بألوان رائعة تنعش الروح. يتسلق الأفراد الجبال للاستمتاع بإطلالات خلابة تمتد لمسافات بعيدة. تتساقط حبات المطر على الأرض، محدثةً نغمة هادئة ومريحة. الطبيعة تعلمنا السكينة والتوازن، وتذكيرنا بأن الحياة تنمو وتتجدد دائمًا كما تفعل الأزهار في فصل الربيع.
"""
summarized_text = summarize_arabic_text(arabic_text)
print("Original Text:\n", arabic_text)
print("\nSummarized Text:\n", summarized_text)
# Out:
# Original Text:
#
# الطبيعة تمتلك جمالًا لا يضاهى. في قلب الغابة الكثيفة، تنمو الأزهار بألوان رائعة تنعش الروح. يتسلق الأفراد الجبال للاستمتاع بإطلالات خلابة تمتد لمسافات بعيدة. تتساقط حبات المطر على الأرض، محدثةً نغمة هادئة ومريحة. الطبيعة تعلمنا السكينة والتوازن، وتذكيرنا بأن الحياة تنمو وتتجدد دائمًا كما تفعل الأزهار في فصل الربيع.
#
#
# Summarized Text:
#  يتسلق الأفراد الجبال للاستمتاع بإطلالات خلابة تمتد لمسافات بعيدة. وتذكيرنا بأن الحياة تنمو وتتجدد دائمًا كما تفعل الأزهار في فصل الربيع.

# %%
arabic_text = """
الطبيعة تمتلك جمالًا لا يضاهى، ففي قلب الغابة تنمو الأزهار بألوان رائعة. الأفراد يتسلقون الجبال للاستمتاع بإطلالات خلابة. حيث تتساقط حبات المطر، تحدث نغمة هادئة ومريحة. الطبيعة تعلمنا السكينة والتوازن، تذكيرًا بأن الحياة تنمو وتتجدد دائمًا.
"""
summarized_text = summarize_arabic_text(arabic_text)
print("Original Text:\n", arabic_text)
print("\nSummarized Text:\n", summarized_text)
# Out:
# Original Text:
#
# الطبيعة تمتلك جمالًا لا يضاهى، ففي قلب الغابة تنمو الأزهار بألوان رائعة. الأفراد يتسلقون الجبال للاستمتاع بإطلالات خلابة. حيث تتساقط حبات المطر، تحدث نغمة هادئة ومريحة. الطبيعة تعلمنا السكينة والتوازن، تذكيرًا بأن الحياة تنمو وتتجدد دائمًا.
#
#
# Summarized Text:
#  ففي قلب الغابة تنمو الأزهار بألوان رائعة. الأفراد يتسلقون الجبال للاستمتاع بإطلالات خلابة.

# %%
pip install spacy
# Out:
# Requirement already satisfied: spacy in /usr/local/lib/python3.10/dist-packages (3.6.1)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in /usr/local/lib/python3.10/dist-packages (from spacy) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from spacy) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.10/dist-packages (from spacy) (1.0.10)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.10/dist-packages (from spacy) (2.0.8)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /usr/local/lib/python3.10/dist-packages (from spacy) (3.0.9)
# Requirement already satisfied: thinc<8.2.0,>=8.1.8 in /usr/local/lib/python3.10/dist-packages (from spacy) (8.1.12)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in /usr/local/lib/python3.10/dist-packages (from spacy) (1.1.2)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /usr/local/lib/python3.10/dist-packages (from spacy) (2.4.8)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /usr/local/lib/python3.10/dist-packages (from spacy) (2.0.10)
# Requirement already satisfied: typer<0.10.0,>=0.3.0 in /usr/local/lib/python3.10/dist-packages (from spacy) (0.9.0)
# Requirement already satisfied: pathy>=0.10.0 in /usr/local/lib/python3.10/dist-packages (from spacy) (0.10.3)
# Requirement already satisfied: smart-open<7.0.0,>=5.2.1 in /usr/local/lib/python3.10/dist-packages (from spacy) (6.4.0)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /usr/local/lib/python3.10/dist-packages (from spacy) (4.66.1)
# Requirement already satisfied: numpy>=1.15.0 in /usr/local/lib/python3.10/dist-packages (from spacy) (1.23.5)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from spacy) (2.31.0)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 in /usr/local/lib/python3.10/dist-packages (from spacy) (1.10.13)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from spacy) (3.1.2)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from spacy) (67.7.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from spacy) (23.2)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /usr/local/lib/python3.10/dist-packages (from spacy) (3.3.0)
# Requirement already satisfied: typing-extensions>=4.2.0 in /usr/local/lib/python3.10/dist-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (4.5.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy) (2023.7.22)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in /usr/local/lib/python3.10/dist-packages (from thinc<8.2.0,>=8.1.8->spacy) (0.7.11)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in /usr/local/lib/python3.10/dist-packages (from thinc<8.2.0,>=8.1.8->spacy) (0.1.3)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in /usr/local/lib/python3.10/dist-packages (from typer<0.10.0,>=0.3.0->spacy) (8.1.7)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->spacy) (2.1.3)

# %%
# !python -m spacy download xx_ent_wiki_sm
# Out:
# 2023-11-16 08:40:24.420251: E tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:9342] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2023-11-16 08:40:24.420337: E tensorflow/compiler/xla/stream_executor/cuda/cuda_fft.cc:609] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2023-11-16 08:40:24.420388: E tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:1518] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2023-11-16 08:40:24.434535: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-11-16 08:40:28.021746: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# Collecting xx-ent-wiki-sm==3.6.0
#   Downloading https://github.com/explosion/spacy-models/releases/download/xx_ent_wiki_sm-3.6.0/xx_ent_wiki_sm-3.6.0-py3-none-any.whl (11.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.1/11.1 MB 39.8 MB/s eta 0:00:00
# Requirement already satisfied: spacy<3.7.0,>=3.6.0 in /usr/local/lib/python3.10/dist-packages (from xx-ent-wiki-sm==3.6.0) (3.6.1)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in /usr/local/lib/python3.10/dist-packages (from spacy<3.7.0,>=3.6.0->xx-ent-wiki-sm==3.6.0) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.7.0,>=3.6.0->xx-ent-wiki-sm==3.6.0) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.7.0,>=3.6.0->xx-ent-wiki-sm==3.6.0) (1.0.10)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.10/dist-packages (from spacy<3.7.0,>=3.6.0->xx-ent-wiki-sm==3.6.0) (2.0.8)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /usr/local/lib/python3.10/dist-packages (from spacy<3.7.0,>=3.6.0->xx-ent-wiki-sm==3.6.0) (3.0.9)
# Requirement already satisfied: thinc<8.2.0,>=8.1.8 in /usr/local/lib/python3.10/dist-packages (from spacy<3.7.0,>=3.6.0->xx-ent-wiki-sm==3.6.0) (8.1.12)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in /usr/local/lib/python3.10/dist-packages (from spacy<3.7.0,>=3.6.0->xx-ent-wiki-sm==3.6.0) (1.1.2)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /usr/local/lib/python3.10/dist-packages (from spacy<3.7.0,>=3.6.0->xx-ent-wiki-sm==3.6.0) (2.4.8)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /usr/local/lib/python3.10/dist-packages (from spacy<3.7.0,>=3.6.0->xx-ent-wiki-sm==3.6.0) (2.0.10)
# Requirement already satisfied: typer<0.10.0,>=0.3.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.7.0,>=3.6.0->xx-ent-wiki-sm==3.6.0) (0.9.0)
# Requirement already satisfied: pathy>=0.10.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.7.0,>=3.6.0->xx-ent-wiki-sm==3.6.0) (0.10.3)
# Requirement already satisfied: smart-open<7.0.0,>=5.2.1 in /usr/local/lib/python3.10/dist-packages (from spacy<3.7.0,>=3.6.0->xx-ent-wiki-sm==3.6.0) (6.4.0)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.7.0,>=3.6.0->xx-ent-wiki-sm==3.6.0) (4.66.1)
# Requirement already satisfied: numpy>=1.15.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.7.0,>=3.6.0->xx-ent-wiki-sm==3.6.0) (1.23.5)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.7.0,>=3.6.0->xx-ent-wiki-sm==3.6.0) (2.31.0)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 in /usr/local/lib/python3.10/dist-packages (from spacy<3.7.0,>=3.6.0->xx-ent-wiki-sm==3.6.0) (1.10.13)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from spacy<3.7.0,>=3.6.0->xx-ent-wiki-sm==3.6.0) (3.1.2)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from spacy<3.7.0,>=3.6.0->xx-ent-wiki-sm==3.6.0) (67.7.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.7.0,>=3.6.0->xx-ent-wiki-sm==3.6.0) (23.2)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.7.0,>=3.6.0->xx-ent-wiki-sm==3.6.0) (3.3.0)
# Requirement already satisfied: typing-extensions>=4.2.0 in /usr/local/lib/python3.10/dist-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.7.0,>=3.6.0->xx-ent-wiki-sm==3.6.0) (4.5.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.7.0,>=3.6.0->xx-ent-wiki-sm==3.6.0) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.7.0,>=3.6.0->xx-ent-wiki-sm==3.6.0) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.7.0,>=3.6.0->xx-ent-wiki-sm==3.6.0) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.7.0,>=3.6.0->xx-ent-wiki-sm==3.6.0) (2023.7.22)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in /usr/local/lib/python3.10/dist-packages (from thinc<8.2.0,>=8.1.8->spacy<3.7.0,>=3.6.0->xx-ent-wiki-sm==3.6.0) (0.7.11)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in /usr/local/lib/python3.10/dist-packages (from thinc<8.2.0,>=8.1.8->spacy<3.7.0,>=3.6.0->xx-ent-wiki-sm==3.6.0) (0.1.3)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in /usr/local/lib/python3.10/dist-packages (from typer<0.10.0,>=0.3.0->spacy<3.7.0,>=3.6.0->xx-ent-wiki-sm==3.6.0) (8.1.7)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->spacy<3.7.0,>=3.6.0->xx-ent-wiki-sm==3.6.0) (2.1.3)
# Installing collected packages: xx-ent-wiki-sm
# Successfully installed xx-ent-wiki-sm-3.6.0
# ✔ Download and installation successful
# You can now load the package via spacy.load('xx_ent_wiki_sm')

# %%
import spacy

# Load the Arabic language model
nlp = spacy.load('xx_ent_wiki_sm')

# Process Arabic text
text = "اللغة العربية جميلة"
doc = nlp(text)

# Print tokenized words and their POS tags
for token in doc:
    print(token.text, token.pos_)
# Out:
# اللغة
# العربية
# جميلة

# %%
import spacy

# Load the Arabic language model
nlp = spacy.load("ar_core_news_sm")

# Example text for summarization
text = """
قالت وزارة الصحة إن عدد الإصابات بفيروس كورونا في البلاد ارتفع إلى 1000 حالة. وذكرت الوزارة أنه تم تسجيل 50 حالة جديدة اليوم. كما تم تسجيل 5 حالات وفاة جديدة. تعمل الحكومة على تنفيذ إجراءات احترازية للحد من انتشار الفيروس.
"""

# Process the text
doc = nlp(text)

# Extract sentences and scores
sentences = [sent.text for sent in doc.sents]
scores = [sent._.trank for sent in doc.sents]

# Sort sentences by score
sorted_sentences = [sent for _, sent in sorted(zip(scores, sentences), reverse=True)]

# Set the desired summary length (number of sentences)
summary_length = 2

# Generate the summary
summary = " ".join(sorted_sentences[:summary_length])

# Print the summary
print("Summary:")
print(summary)
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-19-238001ee02f0> in <cell line: 4>()
#       2
#       3 # Load the Arabic language model
# ----> 4 nlp = spacy.load("ar_core_news_sm")
#       5
#       6 # Example text for summarization
#
# /usr/local/lib/python3.10/dist-packages/spacy/__init__.py in load(name, vocab, disable, enable, exclude, config)
#      49     RETURNS (Language): The loaded nlp object.
#      50     """
# ---> 51     return util.load_model(
#      52         name,
#      53         vocab=vocab,
#
# /usr/local/lib/python3.10/dist-packages/spacy/util.py in load_model(name, vocab, disable, enable, exclude, config)
#     470     if name in OLD_MODEL_SHORTCUTS:
#     471         raise IOError(Errors.E941.format(name=name, full=OLD_MODEL_SHORTCUTS[name]))  # type: ignore[index]
# --> 472     raise IOError(Errors.E050.format(name=name))
#     473
#     474
#
# OSError: [E050] Can't find model 'ar_core_news_sm'. It doesn't seem to be a Python package or a valid path to a data directory.

# %%
from nltk.corpus import stopwords
from nltk.tokenize import sent_tokenize
from nltk.stem.isri import ISRIStemmer

# Example text for summarization
text = """
قالت وزارة الصحة إن عدد الإصابات بفيروس كورونا في البلاد ارتفع إلى 1000 حالة. وذكرت الوزارة أنه تم تسجيل 50 حالة جديدة اليوم. كما تم تسجيل 5 حالات وفاة جديدة. تعمل الحكومة على تنفيذ إجراءات احترازية للحد من انتشار الفيروس.
"""

# Tokenize the text into sentences
sentences = sent_tokenize(text)

# Remove stopwords
stop_words = set(stopwords.words('arabic'))
filtered_sentences = [sentence for sentence in sentences if sentence.lower() not in stop_words]

# Apply stemming
stemmer = ISRIStemmer()
stemmed_sentences = [stemmer.stem(sentence) for sentence in filtered_sentences]

# Set the desired summary length (number of sentences)
summary_length = 2

# Generate the summary
summary = ". ".join(stemmed_sentences[:summary_length])

# Print the summary
print("Summary:")
print(summary)
# Out:
# Summary:
#
# قالت وزارة الصحة إن عدد الإصابات بفيروس كورونا في البلاد ارتفع إلى 1000 حالة.. وذكرت الوزارة أنه تم تسجيل 50 حالة جديدة اليوم.

# %%
# Example text for summarization
text = """
الطبيعة تمتلك جمالًا لا يضاهى. في قلب الغابة الكثيفة، تنمو الأزهار بألوان رائعة تنعش الروح. يتسلق الأفراد الجبال للاستمتاع بإطلالات خلابة تمتد لمسافات بعيدة. تتساقط حبات المطر على الأرض، محدثةً نغمة هادئة ومريحة. الطبيعة تعلمنا السكينة والتوازن، وتذكيرنا بأن الحياة تنمو وتتجدد دائمًا كما تفعل الأزهار في فصل الربيع.
"""

# Tokenize the text into sentences
sentences = sent_tokenize(text)

# Remove stopwords
stop_words = set(stopwords.words('arabic'))
filtered_sentences = [sentence for sentence in sentences if sentence.lower() not in stop_words]

# Apply stemming
stemmer = ISRIStemmer()
stemmed_sentences = [stemmer.stem(sentence) for sentence in filtered_sentences]

# Set the desired summary length (number of sentences)
summary_length = 2

# Generate the summary
summary = ". ".join(stemmed_sentences[:summary_length])

# Print the summary
print("Summary:")
print(summary)
# Out:
# Summary:
#
# الطبيعة تمتلك جمالا لا يضاهى.. في قلب الغابة الكثيفة، تنمو الأزهار بألوان رائعة تنعش الروح.

# %%
arabic_text = """
الطبيعة تمتلك جمالًا لا يضاهى. في قلب الغابة الكثيفة، تنمو الأزهار بألوان رائعة تنعش الروح. يتسلق الأفراد الجبال للاستمتاع بإطلالات خلابة تمتد لمسافات بعيدة. تتساقط حبات المطر على الأرض، محدثةً نغمة هادئة ومريحة. الطبيعة تعلمنا السكينة والتوازن، وتذكيرنا بأن الحياة تنمو وتتجدد دائمًا كما تفعل الأزهار في فصل الربيع.
"""

# %%
import spacy
from spacy.lang.ar import Arabic

# Load the Arabic language model
nlp = Arabic()

# Example text for summarization
text = """
قالت وزارة الصحة إن عدد الإصابات بفيروس كورونا في البلاد ارتفع إلى 1000 حالة. وذكرت الوزارة أنه تم تسجيل 50 حالة جديدة اليوم. كما تم تسجيل 5 حالات وفاة جديدة. تعمل الحكومة على تنفيذ إجراءات احترازية للحد من انتشار الفيروس.
"""

# Process the text
doc = nlp(text)

# Extract sentences
sentences = [sent.text for sent in doc.sents]

# Set the desired summary length (number of sentences)
summary_length = 2

# Generate the summary
summary = ". ".join(sentences[:summary_length])

# Print the summary
print("Summary:")
print(summary)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-25-993c1551f7c9> in <cell line: 16>()
#      14
#      15 # Extract sentences
# ---> 16 sentences = [sent.text for sent in doc.sents]
#      17
#      18 # Set the desired summary length (number of sentences)
#
# <ipython-input-25-993c1551f7c9> in <listcomp>(.0)
#      14
#      15 # Extract sentences
# ---> 16 sentences = [sent.text for sent in doc.sents]
#      17
#      18 # Set the desired summary length (number of sentences)
#
# /usr/local/lib/python3.10/dist-packages/spacy/tokens/doc.pyx in sents()
#
# ValueError: [E030] Sentence boundaries unset. You can add the 'sentencizer' component to the pipeline with: `nlp.add_pipe('sentencizer')`. Alternatively, add the dependency parser or sentence recognizer, or set sentence boundaries by setting `doc[i].is_sent_start`.

# %%
import spacy
from spacy.lang.ar import Arabic

# Load the Arabic language model
nlp = Arabic()

# Example text for summarization
text = """
قالت وزارة الصحة إن عدد الإصابات بفيروس كورونا في البلاد ارتفع إلى 1000 حالة. وذكرت الوزارة أنه تم تسجيل 50 حالة جديدة اليوم. كما تم تسجيل 5 حالات وفاة جديدة. تعمل الحكومة على تنفيذ إجراءات احترازية للحد من انتشار الفيروس.
"""

# Process the text
doc = nlp(text)

# Extract sentences
sentences = [sent.text for sent in doc.sents]

# Set the desired summary length (number of sentences)
summary_length = 2

# Generate the summary
summary = ". ".join(sentences[:summary_length])

# Print the summary
print("Summary:")
print(summary)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-26-993c1551f7c9> in <cell line: 16>()
#      14
#      15 # Extract sentences
# ---> 16 sentences = [sent.text for sent in doc.sents]
#      17
#      18 # Set the desired summary length (number of sentences)
#
# <ipython-input-26-993c1551f7c9> in <listcomp>(.0)
#      14
#      15 # Extract sentences
# ---> 16 sentences = [sent.text for sent in doc.sents]
#      17
#      18 # Set the desired summary length (number of sentences)
#
# /usr/local/lib/python3.10/dist-packages/spacy/tokens/doc.pyx in sents()
#
# ValueError: [E030] Sentence boundaries unset. You can add the 'sentencizer' component to the pipeline with: `nlp.add_pipe('sentencizer')`. Alternatively, add the dependency parser or sentence recognizer, or set sentence boundaries by setting `doc[i].is_sent_start`.

# %%
import nltk

# %%
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# True

# %%
from transformers import AutoTokenizer, AutoModel
import torch

tokenizer = AutoTokenizer.from_pretrained("asafaya/bert-base-arabic")
model = AutoModel.from_pretrained("asafaya/bert-base-arabic")

# Tokenize and obtain embeddings
input_text = "قالت وزارة الصحة إن عدد الإصابات بفيروس كورونا في البلاد ارتفع إلى 1000 حالة. وذكرت الوزارة أنه تم تسجيل 50 حالة جديدة اليوم. كما تم تسجيل 5 حالات وفاة جديدة. تعمل الحكومة على تنفيذ إجراءات احترازية للحد من انتشار الفيروس."
input_ids = tokenizer.encode(input_text, return_tensors="pt")
outputs = model(input_ids)

# Use the embeddings for similarity comparison
# Out:
# (…)rabic/resolve/main/tokenizer_config.json:   0%|          | 0.00/62.0 [00:00<?, ?B/s]
# (…)ert-base-arabic/resolve/main/config.json:   0%|          | 0.00/491 [00:00<?, ?B/s]
# (…)/bert-base-arabic/resolve/main/vocab.txt:   0%|          | 0.00/334k [00:00<?, ?B/s]
# (…)bic/resolve/main/special_tokens_map.json:   0%|          | 0.00/112 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/445M [00:00<?, ?B/s]

# %%
# Load pre-trained BERT model and tokenizer
tokenizer = AutoTokenizer.from_pretrained("asafaya/bert-base-arabic")
model = AutoModel.from_pretrained("asafaya/bert-base-arabic")

# Input text
input_text = "قالت وزارة الصحة إن عدد الإصابات بفيروس كورونا في البلاد ارتفع إلى 1000 حالة. وذكرت الوزارة أنه تم تسجيل 50 حالة جديدة اليوم. كما تم تسجيل 5 حالات وفاة جديدة. تعمل الحكومة على تنفيذ إجراءات احترازية للحد من انتشار الفيروس."

# Tokenize and obtain embeddings
input_ids = tokenizer.encode(input_text, return_tensors="pt")
with torch.no_grad():
    outputs = model(input_ids)

# Get the embeddings for the [CLS] token (first token in the sequence)
cls_embedding = outputs.last_hidden_state[:, 0, :]

# Use these embeddings for similarity comparison or further processing
# For example, you can print the summarized text
print("Summarized Text:")
print(tokenizer.decode(tokenizer.convert_ids_to_tokens(cls_embedding[0].tolist())))
# Out:
# Summarized Text:
# ---------------------------------------------------------------------------
# OverflowError                             Traceback (most recent call last)
# <ipython-input-34-6779a9cf358e> in <cell line: 19>()
#      17 # For example, you can print the summarized text
#      18 print("Summarized Text:")
# ---> 19 print(tokenizer.decode(tokenizer.convert_ids_to_tokens(cls_embedding[0].tolist())))
#
# /usr/local/lib/python3.10/dist-packages/transformers/tokenization_utils_fast.py in convert_ids_to_tokens(self, ids, skip_special_tokens)
#     390             if skip_special_tokens and index in self.all_special_ids:
#     391                 continue
# --> 392             tokens.append(self._tokenizer.id_to_token(index))
#     393         return tokens
#     394
#
# OverflowError: out of range integral type conversion attempted

# %%
from transformers import AutoTokenizer, AutoModel
import torch

# Load pre-trained BERT model and tokenizer
tokenizer = AutoTokenizer.from_pretrained("asafaya/bert-base-arabic")
model = AutoModel.from_pretrained("asafaya/bert-base-arabic")

# Input text
input_text = "قالت وزارة الصحة إن عدد الإصابات بفيروس كورونا في البلاد ارتفع إلى 1000 حالة. وذكرت الوزارة أنه تم تسجيل 50 حالة جديدة اليوم. كما تم تسجيل 5 حالات وفاة جديدة. تعمل الحكومة على تنفيذ إجراءات احترازية للحد من انتشار الفيروس."

# Tokenize and obtain embeddings
input_ids = tokenizer.encode(input_text, return_tensors="pt")
with torch.no_grad():
    outputs = model(input_ids)

# Get the embeddings for the [CLS] token (first token in the sequence)
cls_embedding = outputs.last_hidden_state[:, 0, :]

# Use the tokenizer's decode method directly
# Specify skip_special_tokens=True to exclude special tokens like [CLS]
decoded_text = tokenizer.decode(input_ids[0], skip_special_tokens=True)

# Print the summarized text
print("Summarized Text:")
print(decoded_text)
# Out:
# Summarized Text:
# قالت وزارة الصحة ان عدد الاصابات بفيروس كورونا في البلاد ارتفع الى 1000 حالة. وذكرت الوزارة انه تم تسجيل 50 حالة جديدة اليوم. كما تم تسجيل 5 حالات وفاة جديدة. تعمل الحكومة على تنفيذ اجراءات احترازية للحد من انتشار الفيروس.

# %%
from transformers import AutoTokenizer, AutoModel
import torch

# Load pre-trained BERT model and tokenizer
tokenizer = AutoTokenizer.from_pretrained("asafaya/bert-base-arabic")
model = AutoModel.from_pretrained("asafaya/bert-base-arabic")

# Input text (random Arabic text)
input_text = "بسم الله الرحمن الرحيم، اليوم هو يوم جميل ومشرق وعظيم وسعيد ولطيف. أتمنى لك يوماً سعيداً ومليئاً بالنجاح والفرح."

# Tokenize and obtain embeddings
input_ids = tokenizer.encode(input_text, return_tensors="pt")
with torch.no_grad():
    outputs = model(input_ids)

# Get the embeddings for the [CLS] token (first token in the sequence)
cls_embedding = outputs.last_hidden_state[:, 0, :]

# Use the tokenizer's decode method directly
# Specify skip_special_tokens=True to exclude special tokens like [CLS]
decoded_text = tokenizer.decode(input_ids[0], skip_special_tokens=True)

# Print the original text
print("Original Text:")
print(input_text)

# Print the summarized text
print("\nSummarized Text:")
print(decoded_text)
# Out:
# Original Text:
# بسم الله الرحمن الرحيم، اليوم هو يوم جميل ومشرق وعظيم وسعيد ولطيف. أتمنى لك يوماً سعيداً ومليئاً بالنجاح والفرح.
#
# Summarized Text:
# بسم الله الرحمن الرحيم ، اليوم هو يوم جميل ومشرق وعظيم وسعيد ولطيف. اتمنى لك يوما سعيدا وملييا بالنجاح والفرح.

# %%
pip install transformers
# Out:
# Collecting transformers
#   Downloading transformers-4.35.2-py3-none-any.whl (7.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.9/7.9 MB 14.3 MB/s eta 0:00:00
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from transformers) (3.13.1)
# Collecting huggingface-hub<1.0,>=0.16.4 (from transformers)
#   Downloading huggingface_hub-0.19.3-py3-none-any.whl (311 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 311.2/311.2 kB 21.4 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (1.23.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from transformers) (23.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (6.0.1)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (2023.6.3)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from transformers) (2.31.0)
# Collecting tokenizers<0.19,>=0.14 (from transformers)
#   Downloading tokenizers-0.15.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.8/3.8 MB 50.8 MB/s eta 0:00:00
# Collecting safetensors>=0.3.1 (from transformers)
#   Downloading safetensors-0.4.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 61.1 MB/s eta 0:00:00
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.10/dist-packages (from transformers) (4.66.1)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.16.4->transformers) (2023.6.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.16.4->transformers) (4.5.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2023.7.22)
# Installing collected packages: safetensors, huggingface-hub, tokenizers, transformers
# Successfully installed huggingface-hub-0.19.3 safetensors-0.4.0 tokenizers-0.15.0 transformers-4.35.2

# %%
import fasttext

# Load the pre-trained model
model = fasttext.load_model('cc.ar.300.bin')

# Get sentence embeddings
# sentence = "Your Arabic sentence here."
embedding = model.get_sentence_vector(input_text)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-39-0c104f52b8d1> in <cell line: 1>()
# ----> 1 import fasttext
#       2
#       3 # Load the pre-trained model
#       4 model = fasttext.load_model('cc.ar.300.bin')
#       5
#
# ModuleNotFoundError: No module named 'fasttext'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
from transformers import AutoTokenizer, AutoModel
import torch
from sklearn.metrics.pairwise import cosine_similarity

# Load pre-trained BERT model and tokenizer
tokenizer = AutoTokenizer.from_pretrained("asafaya/bert-base-arabic")
model = AutoModel.from_pretrained("asafaya/bert-base-arabic")

# Input sentences
sentence1 = "بسم الله الرحمن الرحيم"
sentence2 = "الحمد لله رب العالمين"

# Tokenize and obtain embeddings for each sentence
input_ids1 = tokenizer.encode(sentence1, return_tensors="pt")
input_ids2 = tokenizer.encode(sentence2, return_tensors="pt")

with torch.no_grad():
    outputs1 = model(input_ids1)
    outputs2 = model(input_ids2)

# Get the embeddings for the [CLS] token (first token in the sequence)
embedding1 = outputs1.last_hidden_state[:, 0, :]
embedding2 = outputs2.last_hidden_state[:, 0, :]

# Convert embeddings to numpy arrays
embedding1_np = embedding1.cpu().numpy()
embedding2_np = embedding2.cpu().numpy()

# Calculate cosine similarity
similarity_matrix = cosine_similarity(embedding1_np, embedding2_np)

# The similarity_matrix is a 2x2 matrix, as we are comparing two sentences
# The diagonal elements represent the similarity between each sentence with itself
# The off-diagonal elements represent the similarity between the two sentences
similarity_percentage = similarity_matrix[0, 1] * 100

# Print the similarity percentage
print(f"Similarity between the two sentences: {similarity_percentage:.2f}%")
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-41-ef01412523ee> in <cell line: 35>()
#      33 # The diagonal elements represent the similarity between each sentence with itself
#      34 # The off-diagonal elements represent the similarity between the two sentences
# ---> 35 similarity_percentage = similarity_matrix[0, 1] * 100
#      36
#      37 # Print the similarity percentage
#
# IndexError: index 1 is out of bounds for axis 1 with size 1

# %%
pip install transformers
# Out:
# Requirement already satisfied: transformers in /usr/local/lib/python3.10/dist-packages (4.35.2)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from transformers) (3.13.1)
# Requirement already satisfied: huggingface-hub<1.0,>=0.16.4 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.19.4)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (1.23.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from transformers) (23.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (6.0.1)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (2023.6.3)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from transformers) (2.31.0)
# Requirement already satisfied: tokenizers<0.19,>=0.14 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.15.0)
# Requirement already satisfied: safetensors>=0.3.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.4.0)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.10/dist-packages (from transformers) (4.66.1)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.16.4->transformers) (2023.6.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.16.4->transformers) (4.5.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2023.7.22)

# %%
from transformers import AutoTokenizer, AutoModel
import torch
from sklearn.metrics.pairwise import cosine_similarity

# Load pre-trained BERT model and tokenizer
tokenizer = AutoTokenizer.from_pretrained("asafaya/bert-base-arabic")
model = AutoModel.from_pretrained("asafaya/bert-base-arabic")

# Input sentences
sentence1 = "بسم الله الرحمن الرحيم"
sentence2 = "الحمد لله رب العالمين"

# Tokenize and obtain embeddings for each sentence
input_ids1 = tokenizer.encode(sentence1, return_tensors="pt")
input_ids2 = tokenizer.encode(sentence2, return_tensors="pt")

with torch.no_grad():
    outputs1 = model(input_ids1)
    outputs2 = model(input_ids2)

# Get the embeddings for the [CLS] token (first token in the sequence)
embedding1 = outputs1.last_hidden_state[:, 0, :]
embedding2 = outputs2.last_hidden_state[:, 0, :]

# Convert embeddings to numpy arrays
embedding1_np = embedding1.cpu().numpy()
embedding2_np = embedding2.cpu().numpy()

# Calculate cosine similarity
similarity_matrix = cosine_similarity(embedding1_np, embedding2_np)

# The similarity_matrix is a 1x1 matrix, as we are comparing two vectors
similarity_percentage = similarity_matrix[0][0] * 100

# Print the similarity percentage
print(f"Similarity between the two sentences: {similarity_percentage:.2f}%")
# Out:
# tokenizer_config.json:   0%|          | 0.00/62.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/491 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/334k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/112 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/445M [00:00<?, ?B/s]
# Similarity between the two sentences: 91.55%

# %%
# Input sentences
sentence1 = "بسم الله الرحمن الرحيم"
sentence2 = "اللغة العربية جميلة"

# Tokenize and obtain embeddings for each sentence
input_ids1 = tokenizer.encode(sentence1, return_tensors="pt")
input_ids2 = tokenizer.encode(sentence2, return_tensors="pt")

with torch.no_grad():
    outputs1 = model(input_ids1)
    outputs2 = model(input_ids2)

# Get the embeddings for the [CLS] token (first token in the sequence)
embedding1 = outputs1.last_hidden_state[:, 0, :]
embedding2 = outputs2.last_hidden_state[:, 0, :]

# Convert embeddings to numpy arrays
embedding1_np = embedding1.cpu().numpy()
embedding2_np = embedding2.cpu().numpy()

# Calculate cosine similarity
similarity_matrix = cosine_similarity(embedding1_np, embedding2_np)

# The similarity_matrix is a 1x1 matrix, as we are comparing two vectors
similarity_percentage = similarity_matrix[0][0] * 100

# Print the similarity percentage
print(f"Similarity between the two sentences: {similarity_percentage:.2f}%")
# Out:
# Similarity between the two sentences: 33.93%

# %%
# Input sentences
sentence1 = "أنا أحب اللغة العربية، إنها عظيمة"
sentence2 = "أنا أعشق لغتنا العربية ، إ"

# Tokenize and obtain embeddings for each sentence
input_ids1 = tokenizer.encode(sentence1, return_tensors="pt")
input_ids2 = tokenizer.encode(sentence2, return_tensors="pt")

with torch.no_grad():
    outputs1 = model(input_ids1)
    outputs2 = model(input_ids2)

# Get the embeddings for the [CLS] token (first token in the sequence)
embedding1 = outputs1.last_hidden_state[:, 0, :]
embedding2 = outputs2.last_hidden_state[:, 0, :]

# Convert embeddings to numpy arrays
embedding1_np = embedding1.cpu().numpy()
embedding2_np = embedding2.cpu().numpy()

# Calculate cosine similarity
similarity_matrix = cosine_similarity(embedding1_np, embedding2_np)

# The similarity_matrix is a 1x1 matrix, as we are comparing two vectors
similarity_percentage = similarity_matrix[0][0] * 100

# Print the similarity percentage
print(similarity_matrix[0][0])
print(f"Similarity between the two sentences: {similarity_percentage:.2f}%")
# Out:
# 0.94780284
# Similarity between the two sentences: 94.78%

# %%
import pandas as pd

# %%
# Specify the path to your CSV file
csv_file_path = r'/content/shika2.csv'

# Read the CSV file into a DataFrame
df = pd.read_csv(csv_file_path)

# %%
df
# Out:
#                 User               Date Created  Number of Likes  \
# 0    AhmedHa63833734  2022-07-05 23:51:29+00:00                1
# 1         KsaZamalek  2022-07-05 23:49:48+00:00              128
# 2              zscun  2022-07-05 23:05:20+00:00                0
# 3           wwxx1911  2022-07-05 23:05:18+00:00               71
# 4              zscun  2022-07-05 23:01:20+00:00                5
# ..               ...                        ...              ...
# 496  Mohaned95836384  2022-07-02 20:22:46+00:00                0
# 497      RedaBond_88  2022-07-02 20:16:38+00:00                0
# 498      Ahmad3abdou  2022-07-02 20:11:51+00:00                0
# 499         _Zoobaaa  2022-07-02 20:09:26+00:00                4
# 500        k0razaman  2022-07-02 20:09:02+00:00                0
#
#          Source of Tweet                                              Tweet
# 0    Twitter for Android                                 نسي يقول شيكابالا
# 1    Twitter for Android  أعوذ برب الفلق أعوذ بالله من عينك المدورهشوبير...
# 2     Twitter for iPhone  اعتقد وعلي ما اظن ده كان موسم فضيحة كمال ريشة ...
# 3    Twitter for Android  لمدة ٢٠ سنة بيحاربوا شيكابالا ع إساس انه قليل ...
# 4     Twitter for iPhone  اهو فهيم عمر اللي جايبه مدحت شلبي ده ياما ظلم ...
# ..                   ...                                                ...
# 496  Twitter for Android    انت هاتكره في عيشته يوم من النوم يقول شيكابالا
# 497  Twitter for Android                                           شيكابالا
# 498      Twitter Web App  برضو الزمالك ويلعب جنب الأسطورة شيكابالا ويبقى...
# 499  Twitter for Android  شيكابالا يحطم رقم قياسي جديد حيث استطاع تسجيل ...
# 500  Twitter for Android                                           شيكابالا
#
# [501 rows x 5 columns]

# %%
for i in df["Tweet"]:
  print(i)
# Out:
#  نسي يقول شيكابالا
# أعوذ برب الفلق أعوذ بالله من عينك المدورهشوبير لما اشوف الهجوم بتاعنا و الهجوم بتاع الزمالك زيزو و لا بن شرقى ولا الجزيري ولا شيكابالا لا هجوم تقيل
# اعتقد وعلي ما اظن ده كان موسم فضيحة كمال ريشة فماتش الأهلي مع طلائع الجيش وكان ماتش الدوري وعلي ما اعتقد واقعة شيكابالا دي كانت أمام طلائع الجيش برضه
# لمدة ٢٠ سنة بيحاربوا شيكابالا ع إساس انه قليل الادب وبيعمل مشاكل ومش محترم، لكن ولا حد أخد باله من المسئول الكبير اللي المفروض عاقل وقدوة كابتن سيد عبدالحفيظ اللي هو سبب الفتنه واكثر شخص بيعمل مشاكل في الكورة المصرية
# اهو فهيم عمر اللي جايبه مدحت شلبي ده ياما ظلم الزمالك وبهدلنا منه لله يا مؤمن مرة شيكابالا وهو خارج تبديل اداله انذار وقبل ما يوصل الخط ويخرج اداله الانذار التاني وطرده اه والله زمبؤلك كدة
# خالد الغندور الزمالك حتى الآن مضى مع  لاعبين مصريين و لاعبين أجانب، الزمالك متصدر الدورى رغم مروره بهذه الأزمات وعلى رأي شيكابالا بنكسب بعرقناسبورتبلس
#  نيبوشا مدرب الأهلي القطري عبر قناة الحياة للأسف لم تكن هناك فرصة للعمل مع شيكابالا، أسمع الكثير عنه وكنت أعلم جيدا مدى الطاقة والحب الذي يدفعه للنادي
#  وإيه اللي جاب شيكابالا عندك الساعه دي ؟
#  ادينا واحده شيكابالا ع المنافسين وبالا
#  انا بحترم كل اراء متعب ولما قال كده انا كنت مؤيده تماما ف كلامه الاهلي محتاج حد ذي شيكابالا  ولا حتي باسم مرسي
# يا سلام مستنية اكتب دوري العيال الصغيرة و شيكابالا و احنا بنحتفل بالدوري
#  لا افتكر انه اصغر من شيكابالا بسنة باين
كن الخسارة تكون فى اللاعب الموهوب و الحريف مثل شيكابالا هذا لاعب لا يأتى مثله إلا  بعد عشرات السنين"

# %%
for i in df["Tweet"]:
  sentence2 = i
  # Tokenize and obtain embeddings for each sentence
  input_ids1 = tokenizer.encode(sentence1, return_tensors="pt")
  input_ids2 = tokenizer.encode(sentence2, return_tensors="pt")

  with torch.no_grad():
      outputs1 = model(input_ids1)
      outputs2 = model(input_ids2)

  # Get the embeddings for the [CLS] token (first token in the sequence)
  embedding1 = outputs1.last_hidden_state[:, 0, :]
  embedding2 = outputs2.last_hidden_state[:, 0, :]

  # Convert embeddings to numpy arrays
  embedding1_np = embedding1.cpu().numpy()
  embedding2_np = embedding2.cpu().numpy()

  # Calculate cosine similarity
  similarity_matrix = cosine_similarity(embedding1_np, embedding2_np)

  if similarity_matrix[0][0] > 0.8:
    # The similarity_matrix is a 1x1 matrix, as we are comparing two vectors
    similarity_percentage = similarity_matrix[0][0] * 100
    print(sentence1)
    print(sentence2)
    # Print the similarity percentage
    print(f"Similarity between the two sentences: {similarity_percentage:.2f}%")
    print("-----------------------------------------------------------")
  else:
    continue
# Out:
#  لكن الخسارة تكون فى اللاعب الموهوب و الحريف مثل شيكابالا هذا لاعب لا يأتى مثله إلا  بعد عشرات السنين
# اهو فهيم عمر اللي جايبه مدحت شلبي ده ياما ظلم الزمالك وبهدلنا منه لله يا مؤمن مرة شيكابالا وهو خارج تبديل اداله انذار وقبل ما يوصل الخط ويخرج اداله الانذار التاني وطرده اه والله زمبؤلك كدة
# Similarity between the two sentences: 82.12%
# -----------------------------------------------------------
#  لكن الخسارة تكون فى اللاعب الموهوب و الحريف مثل شيكابالا هذا لاعب لا يأتى مثله إلا  بعد عشرات السنين
# خالد الغندور الزمالك حتى الآن مضى مع  لاعبين مصريين و لاعبين أجانب، الزمالك متصدر الدورى رغم مروره بهذه الأزمات وعلى رأي شيكابالا بنكسب بعرقناسبورتبلس
# Similarity between the two sentences: 81.66%
# -----------------------------------------------------------
#  لكن الخسارة تكون فى اللاعب الموهوب و الحريف مثل شيكابالا هذا لاعب لا يأتى مثله إلا  بعد عشرات السنين
# يجماعة والله حرام تضيعوا وقتكم ف فُرجة ف ماتشات الدوري المصري مفيش لاعيب كورة ف مصر كلهم هجاصين وكلهم حافظين وكلهم لاعيبة مصنوعة بنسبة  ف المية شيكابالا ال هو عنده  سنة تقريبًا أفضل منهم كلهم والكورة ف رجله شيكابالا بيمثل الموهبة الأخيرة الموجودة ف ملاعبنا
# Similarity between the two sentences: 84.10%
# -----------------------------------------------------------
#  لكن الخسارة تكون فى اللاعب الموهوب و الحريف مثل شيكابالا هذا لاعب لا يأتى مثله إلا  بعد عشرات السنين
# لسه مقابل اخو الكابتن شيكابالا الكبير بيقولى يعينى عليهم شايلين الطين من ساعه هدفين الكابتن وماشافوش خير
# Similarity between the two sentences: 80.81%
# -----------------------------------------------------------
#  لكن الخسارة تكون فى اللاعب الموهوب و الحريف مثل شيكابالا هذا لاعب لا يأتى مثله إلا  بعد عشرات السنين
# شيكابالا  الدوري؟ لو تقصد دوري السنادي فـ ده اتحسم خلاص، بنفكر حاليا في دوري السنة الجاية
# Similarity between the two sentences: 81.13%
# -----------------------------------------------------------
#  لكن الخسارة تكون فى اللاعب الموهوب و الحريف مثل شيكابالا هذا لاعب لا يأتى مثله إلا  بعد عشرات السنين
#  في الغالب انك تكون فايز على ارض الخصم ويتعادل امر مقبول لكن كنا نقدر نكسب ودا مفاد تصريحات القائد والكابتن الخلوق شيكابالا
# Similarity between the two sentences: 82.93%
# -----------------------------------------------------------
#  لكن الخسارة تكون فى اللاعب الموهوب و الحريف مثل شيكابالا هذا لاعب لا يأتى مثله إلا  بعد عشرات السنين
#   لو عندكم لاعب عنده ٣٦ سنة وبيعمل زي شيكابالا كنت هتحطه مكان نسر
# Similarity between the two sentences: 82.47%
# -----------------------------------------------------------
#  لكن الخسارة تكون فى اللاعب الموهوب و الحريف مثل شيكابالا هذا لاعب لا يأتى مثله إلا  بعد عشرات السنين
# حق ربنا انا مش شايف دوري السنادي بالسكواد اللي معانا ده ،، وجود فيريرا وبعض نفحات شيكابالا وزيزو وامام هو اللي مخلينا موحودين ،، لكن مش طبيعي ناخد دوري بتلات اربع لعيبة بس  اتمنى اللي ميتسموش يخسرو نقط اكتر واكتر لإننا للأسف هنخسر نقط لسة
# Similarity between the two sentences: 80.66%
# -----------------------------------------------------------
#  لكن الخسارة تكون فى اللاعب الموهوب و الحريف مثل شيكابالا هذا لاعب لا يأتى مثله إلا  بعد عشرات السنين
#  طارق حامد ضيع تاريخه لانه ببساطه فضل الفلوس واستعجل كان مع الزمالك حتي بعد الاعتزال كان هيبقي له مكانه طارق واللي زيه الي مزبله التاريخ وللأسف مخدش من المدعو اينو مثال النهارده هو اتنسي  لا أحد يذكره يبقي الزمالك شامخ بجمهوره العظيم ولعيبته المخلصة وعلي رأسهم شيكابالا
# Similarity between the two sentences: 82.18%
# -----------------------------------------------------------
#  لكن الخسارة تكون فى اللاعب الموهوب و الحريف مثل شيكابالا هذا لاعب لا يأتى مثله إلا  بعد عشرات السنين
#  المشكلة نفس المحكمة رفضت عقوبة شيكابالا ورفضوا تنفيذها والوقتي بينفذو علي عبدالله السعيد لأنها لمصلحة المنافس فيه فساد اكتر من كده
# Similarity between the two sentences: 85.77%
# -----------------------------------------------------------
#  لكن الخسارة تكون فى اللاعب الموهوب و الحريف مثل شيكابالا هذا لاعب لا يأتى مثله إلا  بعد عشرات السنين
# الكلام دا احنا كأهلاوية بنقرنه بالفشل على طول مثلاً في حالة شيكابالا انما في حالة صلاح محسن محتاج مدرب و محتاج لعيبة و محتاج دماغبقاله عندنا في الفريق قد كدة و من اول ما جه لحد دلوقتي بيتقال نفس الكلام بالحرفلعيب فاشل
# Similarity between the two sentences: 80.10%
# -----------------------------------------------------------
#  لكن الخسارة تكون فى اللاعب الموهوب و الحريف مثل شيكابالا هذا لاعب لا يأتى مثله إلا  بعد عشرات السنين
#  العيب في لاعبيتنا الاشباح مش عند الفرق التانية دا شيكابالا الميت بترد فيه الروح قدامهم يا مؤمن
# Similarity between the two sentences: 83.14%
# -----------------------------------------------------------
#  لكن الخسارة تكون فى اللاعب الموهوب و الحريف مثل شيكابالا هذا لاعب لا يأتى مثله إلا  بعد عشرات السنين
# مهما كانت نجومية اللاعبفنادى القيم والمبادئ نادينا العظيم الاهلىفلن يلعب ضمن صفوفهطالما فكر فقط فى تغيير انتمائه وهذا ما حدث مع عبد الله السعيدولكنماذا حدث مع المنافس شيكابالا مضى ونزل التدريبثم طلب عقوده وردها الاهلى بكل هدوءوجعلوه اسطورةكذلك جمال حمزه ووائل القبانى
# Similarity between the two sentences: 85.61%
# -----------------------------------------------------------
#  لكن الخسارة تكون فى اللاعب الموهوب و الحريف مثل شيكابالا هذا لاعب لا يأتى مثله إلا  بعد عشرات السنين
#   طيب تيجي نحللك تعليقك كده اولا فنياباعتراف اي مدرب اجنبي او اي لاعب واجه شيكابالا وحتى من لعب للأهلي قالو ان شيكابالا أعلى لاعب في الدوري المصري فنياأخلاقيا اظن ان شيكابالا اول ظهور ليه في اي برامج كان على قناه الاهلي بعد حادثه بورسعيد واللي تبرع بيه لأسر الضحايا لوحده
# Similarity between the two sentences: 83.63%
# -----------------------------------------------------------
#  لكن الخسارة تكون فى اللاعب الموهوب و الحريف مثل شيكابالا هذا لاعب لا يأتى مثله إلا  بعد عشرات السنين
#  أبو تريكة كان صانع ألعاب وملعبش نص زمن شيكابالا تعرف حاطط فيكم كام جون  بيبو ، اللاعب المصري المحلي الوحيد اللي أخد أفضل لاعب في أفريقيا  محمود علاء ابننا أصلاً  واحنا مسامحينه
# Similarity between the two sentences: 82.74%
# -----------------------------------------------------------
#  لكن الخسارة تكون فى اللاعب الموهوب و الحريف مثل شيكابالا هذا لاعب لا يأتى مثله إلا  بعد عشرات السنين
#  سؤاااااااال برئ  هل ينفع بأي حال من الاحوال انك تقارن محمد شريف بالمسمي شيكابالا ؟؟؟ولا فنياً ولا أخلاقياً ولا حتي شكلياً
# Similarity between the two sentences: 82.61%
# -----------------------------------------------------------
#  لكن الخسارة تكون فى اللاعب الموهوب و الحريف مثل شيكابالا هذا لاعب لا يأتى مثله إلا  بعد عشرات السنين
#  انت عيل م ع ر ص اوي، يعني الطبيعي لما اللعيبة يتساووا في الأهداف ان الترتيب يبقى حسب الأبجدية لكن انت عشان أهلاوي خل بترتبهم على أساس لعيبة الأهلي الأول، سميها إحصائيات جهلاوية يالا و خليك متصالح مع نفسك و مع الخرم اللي في طيزـك اللي عمله شيكابالا
# Similarity between the two sentences: 80.10%
# -----------------------------------------------------------
#  لكن الخسارة تكون فى اللاعب الموهوب و الحريف مثل شيكابالا هذا لاعب لا يأتى مثله إلا  بعد عشرات السنين
#   هي المحكمة الرياضيةدي مش كانت لغت عقوبة شيكابالا واتحاد الكورة قالك أحكامها غير إلزامية واستمر تنفيذ العقوبة هي على الكيف لصالح الزمالك غير إلزامية في صالح المنافس تنفذ  ايه الكلام الفاضيده زي الحاج يقولك اصل أخذنا بروح القانون وراعينا الحالة النفسية بعد الهزيمة بجاحه وتدليس
# Similarity between the two sentences: 80.70%
# -----------------------------------------------------------
#  لكن الخسارة تكون فى اللاعب الموهوب و الحريف مثل شيكابالا هذا لاعب لا يأتى مثله إلا  بعد عشرات السنين
#  مازالت القضية منظورة أمام المحكمة الرياضية الدولية   كيف ينفذ حكم مستأنف عليه أصلا  ومن متى بتنفذ أحكام مركز البتاع إللى إسمه مركز التسوية دهأمال مع شيكابالا ماتنفذش ليه
# Similarity between the two sentences: 81.94%
# -----------------------------------------------------------
#  لكن الخسارة تكون فى اللاعب الموهوب و الحريف مثل شيكابالا هذا لاعب لا يأتى مثله إلا  بعد عشرات السنين
#   عندك حق بس أنت فاكرني زمالكاوي ، فوق يا سيدي أنا اهلاوي يعني لو لعبت بلاعيبتي بس في أي دوري أوربي أول سنتين تلاته هاخد مركز متوسط و بعد كدة هنافس ، أنت مش هتفهم ثقتي في فريقي و لا هتعرف تتوقع مستوي فريقي لأنك غصب عنك مظلوم اخرك بتفرح لما أخسر و لما شيكابالا يجيب فيا جول
# Similarity between the two sentences: 81.41%
# -----------------------------------------------------------
#  لكن الخسارة تكون فى اللاعب الموهوب و الحريف مثل شيكابالا هذا لاعب لا يأتى مثله إلا  بعد عشرات السنين
#   اتاريه كان الفترة الأخيرة بيلمع في ابن شوبير  وبيقل من شيكابالا  صحيح الجنيه غلاب  احلي من الشرف مافيش
# Similarity between the two sentences: 83.13%
# -----------------------------------------------------------
#  لكن الخسارة تكون فى اللاعب الموهوب و الحريف مثل شيكابالا هذا لاعب لا يأتى مثله إلا  بعد عشرات السنين
#  لا خليني ارص لك القضايا محمد ابراهيم شيكابالا ساسي بوطيب وقريب هيكون طارق حامد اتوكسوا علي عينكم
# Similarity between the two sentences: 85.35%
# -----------------------------------------------------------
#  لكن الخسارة تكون فى اللاعب الموهوب و الحريف مثل شيكابالا هذا لاعب لا يأتى مثله إلا  بعد عشرات السنين
# انا كنت متعلق ب هينري بشكل مرعب كان عامل زي شيكابالا في الزمالك كده فتره  كان هو الفريق حرفيا
# Similarity between the two sentences: 83.61%
# -----------------------------------------------------------
#  لكن الخسارة تكون فى اللاعب الموهوب و الحريف مثل شيكابالا هذا لاعب لا يأتى مثله إلا  بعد عشرات السنين
# باعتراف منهم اللماليم ومن مدربهم السابقشيكابالاالاسطورة
# Similarity between the two sentences: 80.19%
# -----------------------------------------------------------
#  لكن الخسارة تكون فى اللاعب الموهوب و الحريف مثل شيكابالا هذا لاعب لا يأتى مثله إلا  بعد عشرات السنين
# احلام العصاري فعلا  مي حلمي وابراهيم سعيد بيتريقوا على شيكابالا اللي جزمته انضف منهم
# Similarity between the two sentences: 81.42%
# -----------------------------------------------------------
#  لكن الخسارة تكون فى اللاعب الموهوب و الحريف مثل شيكابالا هذا لاعب لا يأتى مثله إلا  بعد عشرات السنين
# الأهلى حكم على ممتلكات عبدالله السعيد على اساس حكم جاى من لجنة التسوية الرياضيه طيب ماهى هى المحكمة ال حكمت برفع إيقاف شيكا بالا بتاع مجاهد ومافيش حاجه حصلت وشيكا كمل الإيقاف كاملا ياعم طيب هى معتمده ولا لا حد يفهمنا
# Similarity between the two sentences: 83.17%
# -----------------------------------------------------------
#  لكن الخسارة تكون فى اللاعب الموهوب و الحريف مثل شيكابالا هذا لاعب لا يأتى مثله إلا  بعد عشرات السنين
#   إذا ضربت فأوجع فإن العاقبة واحده تسلم ايدك وتعيش يادكتور حسين والله قولت كل اللي في نفسيتخيل كلالحزززززءءءءء دا والتنمر على شيكا ويجي ميشيليانكون مدرب الاحمال واللياقه عندهم وينصف شيكابالا
# Similarity between the two sentences: 82.48%
# -----------------------------------------------------------
#  لكن الخسارة تكون فى اللاعب الموهوب و الحريف مثل شيكابالا هذا لاعب لا يأتى مثله إلا  بعد عشرات السنين
# عايزين نجمع نفسنا ونروح نفاجئ لعيبتنا ان شيكابالا هيلم ويشوط ف الجول الماتش الجاي
# Similarity between the two sentences: 80.91%
# -----------------------------------------------------------
#  لكن الخسارة تكون فى اللاعب الموهوب و الحريف مثل شيكابالا هذا لاعب لا يأتى مثله إلا  بعد عشرات السنين
# محكمة التسوية أقرت ببطلان عقوبة شيكابالا الإعلام الأحمر مش مهم وكلامها غير ملزم وهو والعدم سواء طيب تغرم عبدالله السعيد لمصلحة الاهلي لا ياعبدالله اقولك ايه محكمة التسوية حكمت عليك بمليون دولار هاتهم يا نحجز علي ممتلكاتك فيه فساد اكتر من كده في العالم يامنظومة عااااااار
# Similarity between the two sentences: 81.69%
# -----------------------------------------------------------
#  لكن الخسارة تكون فى اللاعب الموهوب و الحريف مثل شيكابالا هذا لاعب لا يأتى مثله إلا  بعد عشرات السنين
#  بصي حق الاهلي ربنا بيجيبه خصوصا الخطيب  الجمهور على التواصل الاجتماعي مش عارف الاهلي خصوصا الاندر ايدج احنا الجيل القديم كنا في المدرجات خصوصا سكان القاهرة والله شيكابالا في ماتش الاهلي بطه بلدي من الجمهور وغيرة مدربين ورؤساء أندية وحكام كل كلب يجي على الاهلي
# Similarity between the two sentences: 82.62%
# -----------------------------------------------------------
#  لكن الخسارة تكون فى اللاعب الموهوب و الحريف مثل شيكابالا هذا لاعب لا يأتى مثله إلا  بعد عشرات السنين
# الأجانب منصفين الأجانب عاوزين الكفاءة الأجانب عاوزين الجوده مفيش مدرب أجنبي جه مصر إلا وما قال ف شيكابالا الكثير انا عندي اقتناع تام أن لو مدرب مصري مش هيدي شيكابالا حقه علشان ياخد لقطه الأجانب عندهم عدل شكرا يانكون
# Similarity between the two sentences: 82.45%
# -----------------------------------------------------------
#  لكن الخسارة تكون فى اللاعب الموهوب و الحريف مثل شيكابالا هذا لاعب لا يأتى مثله إلا  بعد عشرات السنين
# مركز التسوية والتحكيم اللي الأهلي اللي اهلي اخد منه حكم بتغريم عبدالله السعيد ٢ مليون دولار هو نفس المركز اللي رفع ايقاف مجاهد ضد شيكابالا لكن ساعتها الكل قال غير ملزم دلوقتى للأهلي نجري بسرعة ننفذ حكم صدر حكم ضده من المحكمة الرياضية الدولية
# Similarity between the two sentences: 81.34%
# -----------------------------------------------------------
#  لكن الخسارة تكون فى اللاعب الموهوب و الحريف مثل شيكابالا هذا لاعب لا يأتى مثله إلا  بعد عشرات السنين
# فشخهم قبل كده و شكله حيكمل عليهمأصيع لاعب فى مصرلو عضم فى قفه لازم ينهى فى الزمالك و نحرق دمهمالزمالك  شيكابالا
# Similarity between the two sentences: 86.14%
# -----------------------------------------------------------
#  لكن الخسارة تكون فى اللاعب الموهوب و الحريف مثل شيكابالا هذا لاعب لا يأتى مثله إلا  بعد عشرات السنين
# خير اللهم اجعله خيرشايفة شيكابالا وهو بيلم ف الكورة ويبحبحها عشان يجيب هدف يوم
# Similarity between the two sentences: 80.32%
# -----------------------------------------------------------
#  لكن الخسارة تكون فى اللاعب الموهوب و الحريف مثل شيكابالا هذا لاعب لا يأتى مثله إلا  بعد عشرات السنين
#  اللاعب  المجتهد  من نوعية طارق حامد بقليل من البحث و التدريب ستجد بديلا عنه لكن الخسارة تكون فى اللاعب الموهوب و الحريف مثل شيكابالا  هذا لاعب لا يأتى مثله إلا  بعد عشرات السنين
# Similarity between the two sentences: 94.56%
# -----------------------------------------------------------
#  لكن الخسارة تكون فى اللاعب الموهوب و الحريف مثل شيكابالا هذا لاعب لا يأتى مثله إلا  بعد عشرات السنين
#  هو مش المركز ده اللي أصدر قرار بوقف عقوبة شيكابالا و اتحاد الكرة منفذش الحكم وشيكابالا أخد العقوبة كلها ؟
# Similarity between the two sentences: 80.16%
# -----------------------------------------------------------
#  لكن الخسارة تكون فى اللاعب الموهوب و الحريف مثل شيكابالا هذا لاعب لا يأتى مثله إلا  بعد عشرات السنين
# ميشيل يانكون عند نزول شيكابالا في مباريات القمة اشعر بالخوف والقلق والجميع داخل النادى الأهلى كذلك   عشنا هذه اللحظات جميعا
# Similarity between the two sentences: 83.63%
# -----------------------------------------------------------
#  لكن الخسارة تكون فى اللاعب الموهوب و الحريف مثل شيكابالا هذا لاعب لا يأتى مثله إلا  بعد عشرات السنين
#  مفيش شك ان شيكابالا لاعب كبير وحريف هو عيبه ثباته الانفعالى فقط
# Similarity between the two sentences: 86.00%
# -----------------------------------------------------------
#  لكن الخسارة تكون فى اللاعب الموهوب و الحريف مثل شيكابالا هذا لاعب لا يأتى مثله إلا  بعد عشرات السنين
#  حاطط صورة شيكابالا وكمان بيقول جمهور الزمالك نصف الشعب المصري علي الاقل ربنا يشفي
# Similarity between the two sentences: 84.39%
# -----------------------------------------------------------
#  لكن الخسارة تكون فى اللاعب الموهوب و الحريف مثل شيكابالا هذا لاعب لا يأتى مثله إلا  بعد عشرات السنين
#  من وجهت نظرى الافضل شيكابالا ومن بعده صلاح ثم حسام حسن و تريزيجيه والخطيب وتريكه
# Similarity between the two sentences: 81.21%
# -----------------------------------------------------------
#  لكن الخسارة تكون فى اللاعب الموهوب و الحريف مثل شيكابالا هذا لاعب لا يأتى مثله إلا  بعد عشرات السنين
#   اولا محدش من جماهير الاهلي عمره شتم ابن شيكابالا هما بيشتموا أبوه وديه معروفة من زمانلكن عماد متعب اللي عمره مغلط فيكم شتمتوا مراتوا ولا نسيت
# Similarity between the two sentences: 82.86%
# -----------------------------------------------------------
#  لكن الخسارة تكون فى اللاعب الموهوب و الحريف مثل شيكابالا هذا لاعب لا يأتى مثله إلا  بعد عشرات السنين
#    يا دكتوره مفيش توسط من شيكا ونفوا الكلام ده وقالوا إن شيكابالا لم يتوسط وكل هذا إشعات ضد إستقرار الفريق
# Similarity between the two sentences: 85.16%
# -----------------------------------------------------------
#  لكن الخسارة تكون فى اللاعب الموهوب و الحريف مثل شيكابالا هذا لاعب لا يأتى مثله إلا  بعد عشرات السنين
#  اقولك الحق بعيدا عن مستواه الفنى أو أسلوب لعبه نختلف أو نتفق عليه لكن طارق حامد محترم مالهوش فى مواقف العيال زى اللى بيعملها شيكابالا أو عبدالله جمعههو بس عايز فلوس مقابل ماقدم معاهم وكان شايل فريقهم حرفيا الفترة السابقهلكن كاخلاق هو محترم مالهوش فى الشو والتحفيل والكام ده
# Similarity between the two sentences: 84.66%
# -----------------------------------------------------------
#  لكن الخسارة تكون فى اللاعب الموهوب و الحريف مثل شيكابالا هذا لاعب لا يأتى مثله إلا  بعد عشرات السنين
#

# -----------------------------------------------------------
#  لكن الخسارة تكون فى اللاعب الموهوب و الحريف مثل شيكابالا هذا لاعب لا يأتى مثله إلا  بعد عشرات السنين
# عايزين نجمع نفسنا ونروح نفاجئ لعيبتنا ان شيكابالا هيلم ويشوط ف الجول الماتش الجاي
# Similarity between the two sentences: 80.91%
# -----------------------------------------------------------
#  لكن الخسارة تكون فى اللاعب الموهوب و الحريف مثل شيكابالا هذا لاعب لا يأتى مثله إلا  بعد عشرات السنين
# عايزين نجمع نفسنا ونروح نفاجئ لعيبتنا ان شيكابالا هيلم ويشوط فالجول الماتش الجاي
# Similarity between the two sentences: 81.91%
# -----------------------------------------------------------
#  لكن الخسارة تكون فى اللاعب الموهوب و الحريف مثل شيكابالا هذا لاعب لا يأتى مثله إلا  بعد عشرات السنين
#  ياراجل والله هو اللى خرب الفرقة ومشى موسيمانى وعايز يمشى عبد الحفيظ بس مش عارف وهايلغى لجنة التخطيط أو يهمشهاومشى بانون وهايفضى الفرقة وهايقسم الأهلى قريبعاملينه رمز وأسطورة وهو أونطجى ونصاب زى شيكابالاده غلطة الخطيب الكبرىغالى لا يمثلنىمش هاينولها إن شاء الله
# Similarity between the two sentences: 81.73%
# -----------------------------------------------------------
#  لكن الخسارة تكون فى اللاعب الموهوب و الحريف مثل شيكابالا هذا لاعب لا يأتى مثله إلا  بعد عشرات السنين
#  مبلكها أنا الصفحة دي من وقت ما قارنت شيكابالا بمحمد شريف
# Similarity between the two sentences: 83.09%
# -----------------------------------------------------------
#  لكن الخسارة تكون فى اللاعب الموهوب و الحريف مثل شيكابالا هذا لاعب لا يأتى مثله إلا  بعد عشرات السنين
#  في الايام دي لولا الله ثم شيكابالا وشيفو والجمهور كان ننافس عالهبوط حرفيا
# Similarity between the two sentences: 84.13%
# -----------------------------------------------------------
#  لكن الخسارة تكون فى اللاعب الموهوب و الحريف مثل شيكابالا هذا لاعب لا يأتى مثله إلا  بعد عشرات السنين
# عايزين نجمع نفسنا ونروح نفاجئ لعيبتنا ان شيكابالا هيلم ويشوط ف الجول الماتش الجاي
# Similarity between the two sentences: 80.91%
# -----------------------------------------------------------
#  لكن الخسارة تكون فى اللاعب الموهوب و الحريف مثل شيكابالا هذا لاعب لا يأتى مثله إلا  بعد عشرات السنين
# عايزين نجمع نفسنا ونروح نفاجئ لعيبتنا ان شيكابالا هيلم ويشوط ف الجول الماتش الجاي بعد م نكون كسبانين
# Similarity between the two sentences: 81.02%
# -----------------------------------------------------------
#  لكن الخسارة تكون فى اللاعب الموهوب و الحريف مثل شيكابالا هذا لاعب لا يأتى مثله إلا  بعد عشرات السنين
# انا حاسه ان لاعيبة الاهلي الماتش الجاي هتبقي مصدومه وهي شايفة شيكابالا بيلم ويقطم ل جوا
# Similarity between the two sentences: 82.02%
# -----------------------------------------------------------
#  لكن الخسارة تكون فى اللاعب الموهوب و الحريف مثل شيكابالا هذا لاعب لا يأتى مثله إلا  بعد عشرات السنين
# للاسف  حسين الشحات عامل زي اهداف شيكابالا اللي هو مجهوده ملوش لازمه لا وكمان بيضيع مجهود فرقته الاهليفوقالجميع
# Similarity between the two sentences: 86.14%
# -----------------------------------------------------------
#  لكن الخسارة تكون فى اللاعب الموهوب و الحريف مثل شيكابالا هذا لاعب لا يأتى مثله إلا  بعد عشرات السنين
# من دلوقتي ياريت لاعيبة الأهلي تخلي بالها من شيكابالا عشان هيلم ويقطم لجوا ويجيب جول
# Similarity between the two sentences: 82.65%
# -----------------------------------------------------------
#  لكن الخسارة تكون فى اللاعب الموهوب و الحريف مثل شيكابالا هذا لاعب لا يأتى مثله إلا  بعد عشرات السنين
#  المشكله  فى ماتش الاهلى والزمالك  اللى جاى  شيكابالا بيتجرا وبيلعب واللعيبه بتخاف تدخل عليه جامد  ههههه
# Similarity between the two sentences: 80.96%
# -----------------------------------------------------------
#  لكن الخسارة تكون فى اللاعب الموهوب و الحريف مثل شيكابالا هذا لاعب لا يأتى مثله إلا  بعد عشرات السنين
# برضو الزمالك ويلعب جنب الأسطورة شيكابالا ويبقى عمل كل حاجة فى الكورة وتقريبا قفل اللعبةومش مهم كاس العالمالاهلي
# Similarity between the two sentences: 85.31%
# -----------------------------------------------------------

# %%
import pandas as pd

# %%
# Specify the path to your CSV file
csv_file_path = r'/content/Egyptian_tweets333.csv'

# Read the CSV file into a DataFrame
df = pd.read_csv(csv_file_path)

# %%
df
# Out:
#                 User               Date Created  Number of Likes  \
# 0      ahmedlaban442  2022-07-21 23:59:53+00:00                0
# 1    sherymo18542887  2022-07-21 23:59:48+00:00                0
# 2     midowadidegla2  2022-07-21 23:59:39+00:00                6
# 3    Qutaiba67312108  2022-07-21 23:59:39+00:00                0
# 4    Mahmoud89928854  2022-07-21 23:59:36+00:00                1
# ..               ...                        ...              ...
# 994       AHMEDMAVEL  2022-07-21 22:23:44+00:00                1
# 995  AhmedAbdullraz1  2022-07-21 22:23:42+00:00                1
# 996      pinkdreem66  2022-07-21 22:23:40+00:00                0
# 997  K95fXext2QeAbYj  2022-07-21 22:23:34+00:00                0
# 998          Agoosif  2022-07-21 22:23:24+00:00                1
#
#              Source of Tweet  \
# 0        Twitter for Android
# 1         Twitter for iPhone
# 2         Twitter for iPhone
# 3        Twitter for Android
# 4        Twitter for Android
#   إضرب كمان عايز اتوب
# الواحد كل م يفكر ينتحر ميبقاش عايز يموت قد ما بيبقي عايز اللي جواه هو اللي يموت
# بإختصار قرار رحيل موسيماني اللي مطلعه واحد مستحيل يكون لعب كوره ولا فاهملان لا الوقت يسمح ولا اللعيبه دي اصلا تسمح تقبل فكر مدرب عايز يلعب كوره
# انا عايز اعيط علي بن شرقي والله ، الراجل في كل ماتش كبير بيثبتلك انه اهم محترف جيه في تاريخ النادي ، كل ماتش بيبقي اخطر واحد علي مرمي المنافس واكتر واحد بيوصل للجول مساهم في ٣٥ جول لوحده في موسمين ، بن شرقي وينج مش هيتكرر في نادي الزمالك
#  عايز تفرح وتنبسط عشان بترجع بعد كدا تقول حظ
#  عايز اعمل كوت بالفيديو بتاعك وانت بتمشي زي الروبوت لكن بس الشبكة واقعة
# الليله عايز اغني وعايز ارقص وعايز افضل اسقف بس دمااااااغ عنب
# عايز اصاحب واحده اسمها لينا
#  هو اكيد فشنك خصوصا موضوع شناوي اما عملية بيع وشراء اللعيبة فالاهلي يعطي للمدير الفني كل الصلاحيات ده جاب تاو ومبكي ومشي كهربا بس انا متفق في حتة حسام مش انه زعق  لانه صاحب فضل وكمان قريب من اللعيبة وممكن يكون عايز  دور في الفريق بس ابو سيد واقف زي اللقمة في الزور
#  لم ترشح شركه الكره سوااريز ويس منصور كان عايز فيتوريا للعلم فقط
# عايز افهم نظام نومي
#  عايز صورة
#   يا سيدي انا عايز أسقط مالكش دعوة
# عايز اصيح بس مش متضايق فمش عارف اصيح ب ايه
# عايز  اعمل فيلم اسميه الاهبل والعبيط والحرامى رشحوا لى ثلاث شخصيات تنفع للأدوار الثلاثة
#  الاهلى كله عايز إحلال وتجديد من اول الإدارة لحد اصغر واحد فى منظومة الكورة
#  انا عايز الطرب
#  الليله عيد بقى
# عارفين احساس انك تبص على حد كده وتبقى عايز تتف على وشه
# انتوا نمتوا ولا ايه الواحد عايز يعمل داونلود براحتهانترنتغيرمحدودفيمصر
# ربنا يحميك و يبعد عنك الإصابات يبني
# انا مش خايف من  علي قد ماخايف اني اطلع زي مادخلت
# انا عايز أخرج خروجه تنسيني اليومين الي فاتوا و تفرتك جميع حواسي و جهازي العصبي من السعاده
#  أنا مش عايز أوصل الحور العينبس هي ترحمني
# جمهور الاهليعايز اساند ما تديني اماره انكاداره قويه مضغوط عليك من مسئول اطلعقول هنعزرك لكن حقوق تروح  وانته ساكت عفوا يبقي ده اخرك وبكررحسن حمدي ما سمعش كلام مبارك  يرجع الحضري خليكم قد المسوءليه مرتضي شويه واتحاد شويهولجنه حكام شويه واعلام شويتين و قناهالاهلي راحت مننا
# هى دى الليالى اللى الواحد يبقى عايز الزمن يقف عندها بجد  يا رب كتر افراحنا
#   خسارة ماحصلت وقت كنت عايز احضرها
# انا عايز اروح اسكن في حتة بعيدة اوي عن كل حاجة
#  لما منظومة الكورة تتطور وتنضف من أقل حاجه لأكبر حاجه اطلب اللي عايز تطلبه غير كدا ابقى قابلني شفت كوره في مصر
#   يلا يا كوس اومك روح انتاك في حته تانيه هو عينك المحامي بتاعه ولا شايفني عرضت على اومك اقول لك تعالي امسك بتاعي انت واومك ها عايز كمان؟
# عايز أقوّم طريقة المشي
# عارف لما تبقي مش كويس بس مش عايز حد يعرف انك مش كويس بس محتاج حد برضه تقوله وتحكيله انك مش كويس
#  يا باشا سبب وجود موسيماني الرئيسي هو انه كان يفوز بأفريقيا عشان الانتخابات  سيبك بقى من مشروع والكدب اللي عمالين يضحكو بي علينا ده ، قسما بالله مافي حد عايز الاهلي كبير غير جمهوره وبس غير كده كدب
# عايز انام اصحى الاقي كل دا انتهى
# انا عايز اخد ازبليكويتا و الونسو منك و ف نفس الوقت الناس الي انت عايزها انا كمان عايزهم ف سبهم احسنلك مش فاهم برشلونه بيتعامل علي اي اساس دول كمان
#   شفت وصلتنا لفين باستهتارك وعدم تحملك المسؤوليةشكرا ممكن تريح شوية وتاخد نفسك وتجهز صح للموسم الجديدلو عايز تحترف بالسلامة بس ماتضيعناش كدهربنا يسامحك
# اشرحلي تاني عايز اتأكد اني مش فاهم
# كفاية طبطبة بجد على اللاعيبة  اللي مش قد تي شيرت الأهلي يجيب عرض ويغور من بكرة  اللي عايز يكمل يتركن عالدكة لحد ما يفوق وطلع الشباب اديهم فرصة هيموتوا عليها مش زي الكباتن اللي شبعت
#   صح الاهلى اعظم نادى برجالته واللى حصل ده هيفوقه وهياخد الدورى،،بس عايز افهمك حاجة عشان تبقى متابع،،يوم ما اتعادلنا فى الدورى كنت انت هتبقى فارق عنى ب ٥ نقط فى حالة الفوز بالمؤجلات،،دلوقتى انا هفرق عنك ب ٣ نقط لو فزت انت بالماتش المؤجل ،،بس انا موافق ان الاهلى هيفوق وهيكتسح الدورى
#  عايز اتعرف عليك
# عايز حد يرغييي معايا عشان هطق
#   انت لو عايز ليلتك تعدي ما تنطقش تاني بعد اللي قولته ده
# عايز فابريزيو رومانو يجيبلى النتيجه عشان خلاص جضيت
# عايز شوية طاقة وصبر بس أعدي بيهم الكام يوم دول
#  ما انت لسه واكل بقسماط عايز ايه تاني
#  نوااايااا كان عايز يتسلى عليا هو والشباب واللي لسه مخرجاه امبارح بيقولي تعالي ولما الاهلي هيكسب مش هفرح اوي عشانك ربنا كبير
#  انا مش عاجبنى الفيديو اللى كان مع قردو عايز يتأدب عشان يبطل تنطيط
# عايز الشبشب بتاع ام احمد دي
# لا مدير ولا روتين ف العمل الاونلاين انت مدير نفسك وده هدف المؤسسة وف مجال مرح زى السياحه والخدمات لينك القناة الرسمية في تيلجرام لو عايز تتابع معانا وتشتغل معانا ابدأ بالتدريب اشتغلمعانااونلاين
# مش بمزاجه مش عايز و مش لاقي مكان يروحه الواحد مقفول من لعيبه المفضل دي حاجه خرا
#  ده انت عايز تتفرج وتفرح
# خليك الشخص اللي إنتَ عايز تكونه، مش اللي الناس عايزه تشوفه، ملكش دعوة بالناس إعمل كُل اللي إنتَ عايزه حتى لو مش هيعجبهُم وهيتكلموا عليك وينتقدوك، إعمل اللي إنتَ عايزه طالما مش بتغضب ربنا وهتكون مرتاح نفسيًا باللي بتعمله، وما تفكرش في الناس عشان ترتاح
#  لو عايز تعرف مدي امتلاك لاعيبه الاهلي من أساسيات كرة القدم اتفرج لا وليد سليمان وهو بيستلم ويلف ويباصي دا اكبر دليل علي أن لاعبيه الجيل الحالي في الاهلي معظمهم مش بيعرفو يلعبون كوره من الاساس
# هوووي عايز انوم
#  طيزك جامد اوي عايز ادخل زبى فيها
#  ابراهيم السكران  انت عايز تتحبس بقي
# ورايا حاجات لازم تخلص مش عايز انام انا هه
#  عايز واحد زى تريكة اللى مصرفش الشيك علشان أمضت كابتن محمود الخطيب عليها عايزين لاعب زى بركات  عايزين لاعب زى جلبرتو عايزين لاعب بروح حسام غالى ومتعب عايزين كبير يحرك الفرقة مش شارة وخلاص عايز لأعيبة عارفة قيمة الفريق مش واخدة الموضوع سبوبة
# انا عندي فلوس كتيره اوي جنيهلو حد عايز فلوس يقول
# عايز اتناقش مع حد في عدة مواضيع مختلفة
# الي مش عايز الزمالك احنا مش عايزينه دا الي يغلط في الزمالك كلنا عارفينه ، وفاهمينه دا كداب حافظينه دا مهزوم والزمالك لما يقوم كل دول ملهمش لزوم
#  انا قعدت نص ساعة استوعب ليه انسان عايز يتولد ب  ايه الفكرة ، لحد ماستوعبت ،، ف تمام
# عايز اسافر
# عند الغضبألتزم الصمت وفكر في أي خرا تاني في حياتك مع احترامي للناس كلها بس الزملكويهالي بيرنوا عليا او بيبعتولي رسايل يا سيدي انت عايز تقولي ايه مثلااحنا كسبنا مبروكاكتر من كده ه هينكالاهليفوقالجميع
#  ف لقطه معرفش جت ف التليفزيون ولا لاه بعد الجون التانى الباشا كان عايز يطلع من الملعب ومكنش عايز يلعب ويكمل
# اي حد عايز ينكد ع نفسه يسمع عمرو الليثي
#  عندك حد بينصحك ببلوك وهو اللي عايز بلوك ادخل على صفحتو واتاكد
# اكتر حاجة كنت خايف عليها هو جدي فيريرا، مش عايز حد يقرب منه، هما يسمعوا كلامه من على بعد كدا وخلاص، ويحتفلوا معاة براحة خالص، انا عايز اجيب جدي فيريرا احطه في عنيا بجد عشان ميحصلش ليه اي حاحة

# %%
sentence1 = " الأهلى عايز راجل قوي ميخفش من اى حد يكون جريئ الله يرحم أبو الكابتن صالح سليم  خد قرار يخطيب والعب بفريق الشباب بناقص دورى السنه دى واكسب فريق جديد  اهلاوي وافتخر وبعشق النادى الأهلى"

# %%
for i in df["Tweet"]:
  sentence2 = i
  # Tokenize and obtain embeddings for each sentence
  input_ids1 = tokenizer.encode(sentence1, return_tensors="pt")
  input_ids2 = tokenizer.encode(sentence2, return_tensors="pt")

  with torch.no_grad():
      outputs1 = model(input_ids1)
      outputs2 = model(input_ids2)

  # Get the embeddings for the [CLS] token (first token in the sequence)
  embedding1 = outputs1.last_hidden_state[:, 0, :]
  embedding2 = outputs2.last_hidden_state[:, 0, :]

  # Convert embeddings to numpy arrays
  embedding1_np = embedding1.cpu().numpy()
  embedding2_np = embedding2.cpu().numpy()

  # Calculate cosine similarity
  similarity_matrix = cosine_similarity(embedding1_np, embedding2_np)

  if similarity_matrix[0][0] > 0.85:
    # The similarity_matrix is a 1x1 matrix, as we are comparing two vectors
    similarity_percentage = similarity_matrix[0][0] * 100
    print(sentence1)
    print(sentence2)
    # Print the similarity percentage
    print(f"Similarity between the two sentences: {similarity_percentage:.2f}%")
    print("-----------------------------------------------------------")
  else:
    continue
# Out:
#  الأهلى عايز راجل قوي ميخفش من اى حد يكون جريئ الله يرحم أبو الكابتن صالح سليم  خد قرار يخطيب والعب بفريق الشباب بناقص دورى السنه دى واكسب فريق جديد  اهلاوي وافتخر وبعشق النادى الأهلى
#  انا عايز الاهلي بتاع زمان وهبقي كويس والله
# Similarity between the two sentences: 86.53%
# -----------------------------------------------------------
#  الأهلى عايز راجل قوي ميخفش من اى حد يكون جريئ الله يرحم أبو الكابتن صالح سليم  خد قرار يخطيب والعب بفريق الشباب بناقص دورى السنه دى واكسب فريق جديد  اهلاوي وافتخر وبعشق النادى الأهلى
#  الخطيب راحل مؤدب مينفعش يبقا رئيس النادي الأهلي عايز واحد شخصية قويه الكل يخاف منه كنت تسمع صوت مرتضى ده وحسن حمدي رئيس النادي بالجزمه  ياخد على قفاه لكن شوف اللي بيحصل مرتضى ليل نهار يشتم في الاهلي ورموزه ده لسه شاتم سيد عبدالحفيظ على الهواء والقضاء الشامخ يخرجو براءه
# Similarity between the two sentences: 85.83%
# -----------------------------------------------------------
#  الأهلى عايز راجل قوي ميخفش من اى حد يكون جريئ الله يرحم أبو الكابتن صالح سليم  خد قرار يخطيب والعب بفريق الشباب بناقص دورى السنه دى واكسب فريق جديد  اهلاوي وافتخر وبعشق النادى الأهلى
# أنا مبسوطلهم بأمانة بس كنت هبقى مبسوط اكتر لو مش على حسابنالكن عشان شوية معدومي الإحساس اللي كانوا بيسخروا من أب عايز يفرح ابنه ويفرح هو كمان باصطحابه معاه الإستاد يشجعوا الفريق اللي بيحبوه مبروك يا
# Similarity between the two sentences: 86.62%
# -----------------------------------------------------------
#  الأهلى عايز راجل قوي ميخفش من اى حد يكون جريئ الله يرحم أبو الكابتن صالح سليم  خد قرار يخطيب والعب بفريق الشباب بناقص دورى السنه دى واكسب فريق جديد  اهلاوي وافتخر وبعشق النادى الأهلى
# انا عايز اعيط علي بن شرقي والله ، الراجل في كل ماتش كبير بيثبتلك انه اهم محترف جيه في تاريخ النادي ، كل ماتش بيبقي اخطر واحد علي مرمي المنافس واكتر واحد بيوصل للجول مساهم في ٣٥ جول لوحده في موسمين ، بن شرقي وينج مش هيتكرر في نادي الزمالك
# Similarity between the two sentences: 86.55%
# -----------------------------------------------------------
#  الأهلى عايز راجل قوي ميخفش من اى حد يكون جريئ الله يرحم أبو الكابتن صالح سليم  خد قرار يخطيب والعب بفريق الشباب بناقص دورى السنه دى واكسب فريق جديد  اهلاوي وافتخر وبعشق النادى الأهلى
# جمهور الاهليعايز اساند ما تديني اماره انكاداره قويه مضغوط عليك من مسئول اطلعقول هنعزرك لكن حقوق تروح  وانته ساكت عفوا يبقي ده اخرك وبكررحسن حمدي ما سمعش كلام مبارك  يرجع الحضري خليكم قد المسوءليه مرتضي شويه واتحاد شويهولجنه حكام شويه واعلام شويتين و قناهالاهلي راحت مننا
# Similarity between the two sentences: 88.60%
# -----------------------------------------------------------
#  الأهلى عايز راجل قوي ميخفش من اى حد يكون جريئ الله يرحم أبو الكابتن صالح سليم  خد قرار يخطيب والعب بفريق الشباب بناقص دورى السنه دى واكسب فريق جديد  اهلاوي وافتخر وبعشق النادى الأهلى
#  النادى ده عايز واحد زى صالح سليم او حسن حمدى
# Similarity between the two sentences: 85.61%
# -----------------------------------------------------------
#  الأهلى عايز راجل قوي ميخفش من اى حد يكون جريئ الله يرحم أبو الكابتن صالح سليم  خد قرار يخطيب والعب بفريق الشباب بناقص دورى السنه دى واكسب فريق جديد  اهلاوي وافتخر وبعشق النادى الأهلى
#  ياجماعه خلاص موسمانى و مشى واحنا دلوقتى معانا مدرب عايز وقت ومعانا لعيبه خلصانا كوره المطلوب تعديل فى الفريق بالكاملولازم حارس قوى ينافس الشناوى حتى لو خسرنا الدورى
# Similarity between the two sentences: 88.79%
# -----------------------------------------------------------
#  الأهلى عايز راجل قوي ميخفش من اى حد يكون جريئ الله يرحم أبو الكابتن صالح سليم  خد قرار يخطيب والعب بفريق الشباب بناقص دورى السنه دى واكسب فريق جديد  اهلاوي وافتخر وبعشق النادى الأهلى
#  النادي عايز يتغربل فعلاً لان بقي مهزلة ال بيحصل كدا وحرقة دم
# Similarity between the two sentences: 87.30%
# -----------------------------------------------------------
#  الأهلى عايز راجل قوي ميخفش من اى حد يكون جريئ الله يرحم أبو الكابتن صالح سليم  خد قرار يخطيب والعب بفريق الشباب بناقص دورى السنه دى واكسب فريق جديد  اهلاوي وافتخر وبعشق النادى الأهلى
# والاعب عارف انة لو قصر فى المبارة سوف يجلس على الدكة او ان الاهلى سوف يعرضة للبيع كان ها ينزل يأكل النجيلة  لكن اللاعب كسب او خسر سوف يحصل على المال والشهرة يبقى ها يتعب نفسة لية ؟ الخطيب يستقيل لو الاهلى عايز يرجع للانتصارات تانى
# Similarity between the two sentences: 85.81%
# -----------------------------------------------------------
#  الأهلى عايز راجل قوي ميخفش من اى حد يكون جريئ الله يرحم أبو الكابتن صالح سليم  خد قرار يخطيب والعب بفريق الشباب بناقص دورى السنه دى واكسب فريق جديد  اهلاوي وافتخر وبعشق النادى الأهلى
#  م لسه هنقعد دكه هياخدوا مكان ف الفاضي وهنقعد الفريق كله دكه الاهلي عايز تجديد شامل الادراه واللاعيبه
# Similarity between the two sentences: 89.49%
# -----------------------------------------------------------
#  الأهلى عايز راجل قوي ميخفش من اى حد يكون جريئ الله يرحم أبو الكابتن صالح سليم  خد قرار يخطيب والعب بفريق الشباب بناقص دورى السنه دى واكسب فريق جديد  اهلاوي وافتخر وبعشق النادى الأهلى
#  معلش هو ماله الفترة الأخيرة لو فيه حاجة شغلاه بلاش يقف خالص جيله عرض مثلا و عايز يمشى يكلم النادى و يتفضل لكن كده مينفعش بيعمل أخطاء ساذجة
# Similarity between the two sentences: 85.51%
# -----------------------------------------------------------
#  الأهلى عايز راجل قوي ميخفش من اى حد يكون جريئ الله يرحم أبو الكابتن صالح سليم  خد قرار يخطيب والعب بفريق الشباب بناقص دورى السنه دى واكسب فريق جديد  اهلاوي وافتخر وبعشق النادى الأهلى
#  ي اختاه الفريق كله عايز يتغير بالله كل ماتش بناحي ف ام الحوار ده الواحد دمه انحرق من اللاعيبه دي والله الي ف الاهلي حوالي او  لاعبيه يستحقوا يكملوا فيه
# Similarity between the two sentences: 88.48%
# -----------------------------------------------------------
#  الأهلى عايز راجل قوي ميخفش من اى حد يكون جريئ الله يرحم أبو الكابتن صالح سليم  خد قرار يخطيب والعب بفريق الشباب بناقص دورى السنه دى واكسب فريق جديد  اهلاوي وافتخر وبعشق النادى الأهلى
#  عايز ترجع الاهلي رجع بدر رجب للقطاع وربيع ياسين للشباب  شوف هيطلعلك رمضان وترزيجه وكهربا جديد عنيهم حلوه علي اللعيبه اللي جاب ديانج ميهوب رجع الشيخ طه وخليه في الاعلام عادي ايه المشكله
# Similarity between the two sentences: 87.55%
# -----------------------------------------------------------
#  الأهلى عايز راجل قوي ميخفش من اى حد يكون جريئ الله يرحم أبو الكابتن صالح سليم  خد قرار يخطيب والعب بفريق الشباب بناقص دورى السنه دى واكسب فريق جديد  اهلاوي وافتخر وبعشق النادى الأهلى
#  عايز أسأل المدير الفني وقمصان سوالهو انتم شايفين ف  عبد القادر ومحمد هاني دول حاجه احنا مش شايفنها واحد كل باص ليه غلط باستثناء باص واحد كان للخلف والتاني فاتحها سبيل  ومفيش اوڤر طول الماتشللأسف احنا خسرنا نفسنا وخرجنا بره الماتش بالاخطاء بتاعتنا مش كوره من الزمالك والله
# Similarity between the two sentences: 90.11%
# -----------------------------------------------------------
#  الأهلى عايز راجل قوي ميخفش من اى حد يكون جريئ الله يرحم أبو الكابتن صالح سليم  خد قرار يخطيب والعب بفريق الشباب بناقص دورى السنه دى واكسب فريق جديد  اهلاوي وافتخر وبعشق النادى الأهلى
#  ياريت هو فيه مدرب لسه بيلعب  وكمان عايز يعمل ضغط عالى دى اسمها حنيكه
# Similarity between the two sentences: 85.05%
# -----------------------------------------------------------
#  الأهلى عايز راجل قوي ميخفش من اى حد يكون جريئ الله يرحم أبو الكابتن صالح سليم  خد قرار يخطيب والعب بفريق الشباب بناقص دورى السنه دى واكسب فريق جديد  اهلاوي وافتخر وبعشق النادى الأهلى
#   ابن ربيع ياسين عايز جماهير الأهلى تكره فيريرا الراجل ماقلش كده فيريرا قال  كان بامكاننا الفوز بنتيجه اكبر ولكني اخطأت في التغييرات ، اصابه فتوح اربكت حساباتي واثرت على قراراتي في التغييرات
# Similarity between the two sentences: 87.55%
# -----------------------------------------------------------
#  الأهلى عايز راجل قوي ميخفش من اى حد يكون جريئ الله يرحم أبو الكابتن صالح سليم  خد قرار يخطيب والعب بفريق الشباب بناقص دورى السنه دى واكسب فريق جديد  اهلاوي وافتخر وبعشق النادى الأهلى
# الزمالك عمره ما يقف على حد الزمالك اللي يصنع النجوم اللي يحترم النادي نحترمه زي بنشرقي كده يفضل في القلب الباقي انتهي مش عايز اشوف واحد فيهم لابس تيشيرت النادي تاني
# Similarity between the two sentences: 87.14%
# -----------------------------------------------------------
#  الأهلى عايز راجل قوي ميخفش من اى حد يكون جريئ الله يرحم أبو الكابتن صالح سليم  خد قرار يخطيب والعب بفريق الشباب بناقص دورى السنه دى واكسب فريق جديد  اهلاوي وافتخر وبعشق النادى الأهلى
#  اسف على الكلام اسف على الرسالة الطويل ده انا لحد دلوقتي مش شايف كوره حلو من ايه فريق في الدورى المصرى برغم الفوز من الفرق بس الواحد عايز كوره حلو مش اجوان وخلاص مبروك للزمالك انا اهلاوي لو الاهلي لعب حلو وخسرنا مكنش حد هتكلم بس مافيش ولا ده ولا ده ولا ده انا لسه عدي كلام كتير
# Similarity between the two sentences: 86.18%
# -----------------------------------------------------------
#  الأهلى عايز راجل قوي ميخفش من اى حد يكون جريئ الله يرحم أبو الكابتن صالح سليم  خد قرار يخطيب والعب بفريق الشباب بناقص دورى السنه دى واكسب فريق جديد  اهلاوي وافتخر وبعشق النادى الأهلى
#    انت الدوري اللي فات كسبت عشان تعثرات الانتر وان كان تقريبا اسوء موسم لليوفي غير كده انت ماشاء الله كنت برضه بتتعادل وبتخسر من الفرق اللي بتنافس ع الهبوط عايز تشوف مستواك فين شوف ماتش بورتو ف الابطال المجمل الفرقه مكنتش وحشه بس اتوقع بعد اللي انتر ويوفي بيعملوه انت هتضيع الموسم ده
# Similarity between the two sentences: 87.54%
# -----------------------------------------------------------
#  الأهلى عايز راجل قوي ميخفش من اى حد يكون جريئ الله يرحم أبو الكابتن صالح سليم  خد قرار يخطيب والعب بفريق الشباب بناقص دورى السنه دى واكسب فريق جديد  اهلاوي وافتخر وبعشق النادى الأهلى
# اللي معايا واللي عايز يعمل فيها شاويش بيحاول بكل الطُرق يثبت أن الأهلي جامد ومش مهم الخسارة وان اكيد هيزعل عشان متعود علي المكسب ودة يدل اكتر أنه محروق وانا طول القعدة مبردش عليه ياما بقوله امممم بس فحقيقي صياحه طرب نىك
# Similarity between the two sentences: 88.71%
# -----------------------------------------------------------
#  الأهلى عايز راجل قوي ميخفش من اى حد يكون جريئ الله يرحم أبو الكابتن صالح سليم  خد قرار يخطيب والعب بفريق الشباب بناقص دورى السنه دى واكسب فريق جديد  اهلاوي وافتخر وبعشق النادى الأهلى
#  الأهلى محتاج ينضف منك ومن المنيسى ومن الخطيب والاداره الفاشله ولجنه الكوره اللى آخرها تفتح سوبر ماركت انتوا لسه عايشين فى برجكم العاجىخليكم انتوا اهتموا بنادى تانى واقعدوا انبشوا فى مشاكله لغايه ماضحكوا عليكمالنادى عايز ينضف ومن غير زعلهو انتوا هاتفضلوا مسيطرين عليه لأمتى
# Similarity between the two sentences: 87.75%
# -----------------------------------------------------------
#  الأهلى عايز راجل قوي ميخفش من اى حد يكون جريئ الله يرحم أبو الكابتن صالح سليم  خد قرار يخطيب والعب بفريق الشباب بناقص دورى السنه دى واكسب فريق جديد  اهلاوي وافتخر وبعشق النادى الأهلى
#

# -----------------------------------------------------------
#  الأهلى عايز راجل قوي ميخفش من اى حد يكون جريئ الله يرحم أبو الكابتن صالح سليم  خد قرار يخطيب والعب بفريق الشباب بناقص دورى السنه دى واكسب فريق جديد  اهلاوي وافتخر وبعشق النادى الأهلى
# والأهم من كدا عايز حارس تقيل يقعدلك الشناوي دا او حتي ميقعدوش لو انت لسه فاكر ان الشناوي هيرجع لمستواه بس يخوفوا ويخليه راجل زي ما حصل مع إكرامي كدا بالظبط عايز باك شمال يبقي مع معلول عشان يعرفوا انك مش هتبقي اساسي سواء كنت حلو او وحش
# Similarity between the two sentences: 85.01%
# -----------------------------------------------------------
#  الأهلى عايز راجل قوي ميخفش من اى حد يكون جريئ الله يرحم أبو الكابتن صالح سليم  خد قرار يخطيب والعب بفريق الشباب بناقص دورى السنه دى واكسب فريق جديد  اهلاوي وافتخر وبعشق النادى الأهلى
# طيب فكرة اني أدعم انسان هو نفسه مش عايز يدعم نفسه يبقي غباء منيلاعبي الاهلي مش عايزين دعم لاعبي الاهلي عايزين إزالةمش هدعم لاعب مش عايز يتعب نفسه
# Similarity between the two sentences: 88.48%
# -----------------------------------------------------------
#  الأهلى عايز راجل قوي ميخفش من اى حد يكون جريئ الله يرحم أبو الكابتن صالح سليم  خد قرار يخطيب والعب بفريق الشباب بناقص دورى السنه دى واكسب فريق جديد  اهلاوي وافتخر وبعشق النادى الأهلى
# وقاعد عمال يعزق ان الاسلوب اللي اتاهل بيه ميليقش باسم ومكانة الاهلي وحجات كدا من اللي بشوفها من العيال بتوع الاهلي عايز يكسب دايما ويلعب حلو حتي برا ملعبه وقدام جماهير الخصم فالواحد مبيتبضنش من اللي بيشجعوا الاهلي دول من فراغ والله المهم كابتن وائل نفسي اعرف رايه حاليا عامل ازاي
# Similarity between the two sentences: 86.59%
# -----------------------------------------------------------
#  الأهلى عايز راجل قوي ميخفش من اى حد يكون جريئ الله يرحم أبو الكابتن صالح سليم  خد قرار يخطيب والعب بفريق الشباب بناقص دورى السنه دى واكسب فريق جديد  اهلاوي وافتخر وبعشق النادى الأهلى
# والهي تحس فاروق جعفر مدسوس علينا البيه عايز مباراه متكافبه في الشوط التاني داهيه تاخدك انت وأمثالك محمد صلاح يفتح النار على فاروق جعفر أنت ناسي إنك زملكاوي
# Similarity between the two sentences: 85.84%
# -----------------------------------------------------------
#  الأهلى عايز راجل قوي ميخفش من اى حد يكون جريئ الله يرحم أبو الكابتن صالح سليم  خد قرار يخطيب والعب بفريق الشباب بناقص دورى السنه دى واكسب فريق جديد  اهلاوي وافتخر وبعشق النادى الأهلى
# الي يشوف اللقطه يبقي عايز يضرب الشناوي بالنار مستني الدوري الانجليزي معانا ولا ايه
# Similarity between the two sentences: 85.18%
# -----------------------------------------------------------
#  الأهلى عايز راجل قوي ميخفش من اى حد يكون جريئ الله يرحم أبو الكابتن صالح سليم  خد قرار يخطيب والعب بفريق الشباب بناقص دورى السنه دى واكسب فريق جديد  اهلاوي وافتخر وبعشق النادى الأهلى
# لو الشناوي عايز يمشي باسلوبه اللي اصحب مستفز يتفضل يمشي الأهلي اللي عمله وعمل اعظم الاعيبه  لو حارس صغير مش هيكون بالشكل دا انا بحس انه بيتلكك
# Similarity between the two sentences: 86.93%
# -----------------------------------------------------------
#  الأهلى عايز راجل قوي ميخفش من اى حد يكون جريئ الله يرحم أبو الكابتن صالح سليم  خد قرار يخطيب والعب بفريق الشباب بناقص دورى السنه دى واكسب فريق جديد  اهلاوي وافتخر وبعشق النادى الأهلى
#   يا دكتور دا طبيعي علشان جمهورنا الحبيب عايز كدا والدور جاي على الخطيب وعلي المدرب الجديد وبعدهم اللعيبة وكدا يبقي النادي خلص منه كل حاجه والبطولات تروح الزمالك ونقعد نتحسر خد بالك النادي هيضيع لو فضلنا نقول الا فات كان أحلي وانتهى الفريق فين حماة النادي إلا بيهدوه حاليآ بئس
# Similarity between the two sentences: 88.13%
# -----------------------------------------------------------
#  الأهلى عايز راجل قوي ميخفش من اى حد يكون جريئ الله يرحم أبو الكابتن صالح سليم  خد قرار يخطيب والعب بفريق الشباب بناقص دورى السنه دى واكسب فريق جديد  اهلاوي وافتخر وبعشق النادى الأهلى
# اهدي علي نفسك شويه  الوضع الان عايز ضبط نفس  موسيماني واخطاء الاداره هما من ضيعوا الفرقه منذ شهور  ونط من المركب لانه خلص علي الفرقه  وكان شطب خلاص معندوش جديد ؟  احنا الان ننسي هذا الموسم  ونعيد بناء الفرقه ولكن لا نهد المعبد  تحياتي
# Similarity between the two sentences: 87.75%
# -----------------------------------------------------------
#  الأهلى عايز راجل قوي ميخفش من اى حد يكون جريئ الله يرحم أبو الكابتن صالح سليم  خد قرار يخطيب والعب بفريق الشباب بناقص دورى السنه دى واكسب فريق جديد  اهلاوي وافتخر وبعشق النادى الأهلى
# عايز أقول حاجة صحيحكىىىىىىمممم النادي الأهلي بتاعكوا
# Similarity between the two sentences: 85.48%
# -----------------------------------------------------------
#  الأهلى عايز راجل قوي ميخفش من اى حد يكون جريئ الله يرحم أبو الكابتن صالح سليم  خد قرار يخطيب والعب بفريق الشباب بناقص دورى السنه دى واكسب فريق جديد  اهلاوي وافتخر وبعشق النادى الأهلى
# عايز فابريزيو رومانو يجيبلى النتيجه عشان خلاص جضيت
# Similarity between the two sentences: 85.17%
# -----------------------------------------------------------
#  الأهلى عايز راجل قوي ميخفش من اى حد يكون جريئ الله يرحم أبو الكابتن صالح سليم  خد قرار يخطيب والعب بفريق الشباب بناقص دورى السنه دى واكسب فريق جديد  اهلاوي وافتخر وبعشق النادى الأهلى
#  نوااايااا كان عايز يتسلى عليا هو والشباب واللي لسه مخرجاه امبارح بيقولي تعالي ولما الاهلي هيكسب مش هفرح اوي عشانك ربنا كبير
# Similarity between the two sentences: 85.08%
# -----------------------------------------------------------
#  الأهلى عايز راجل قوي ميخفش من اى حد يكون جريئ الله يرحم أبو الكابتن صالح سليم  خد قرار يخطيب والعب بفريق الشباب بناقص دورى السنه دى واكسب فريق جديد  اهلاوي وافتخر وبعشق النادى الأهلى
#  حال الفريق مع موسيمانى كان كدا احنا ال بننسى وهو آل دمر لاعبى خط الوسط وهلكهم لإنه كان عايز يكسب ومش مهم مصلحة الفرقه على المدى البعيد جمهور الأهلي أصابه الغرور الرياضة مكسب وهزيمة
# Similarity between the two sentences: 87.64%
# -----------------------------------------------------------
#  الأهلى عايز راجل قوي ميخفش من اى حد يكون جريئ الله يرحم أبو الكابتن صالح سليم  خد قرار يخطيب والعب بفريق الشباب بناقص دورى السنه دى واكسب فريق جديد  اهلاوي وافتخر وبعشق النادى الأهلى
#  مش عايز اشوف اللاعيبه دى تريح بقى ويفضل اللى قلبه على النادى
# Similarity between the two sentences: 86.56%
# -----------------------------------------------------------
#  الأهلى عايز راجل قوي ميخفش من اى حد يكون جريئ الله يرحم أبو الكابتن صالح سليم  خد قرار يخطيب والعب بفريق الشباب بناقص دورى السنه دى واكسب فريق جديد  اهلاوي وافتخر وبعشق النادى الأهلى
#  انا مبخافش ع الاهلي وعمري ما خوفت عليه وبقيت اتقبل اي حاجه تحصل عشان عارف و واثق أن العقول اللي بتديره كبيرة بس انا بقيت خايف من السرطان اللي ظهر فجأة ف النادي وانا مش عايز اذكر اسمه لحد ما حد موثوق منه يطلع يقول إنه ملوش علاقة باللي حصل مع موسيماني
# Similarity between the two sentences: 85.10%
# -----------------------------------------------------------
#  الأهلى عايز راجل قوي ميخفش من اى حد يكون جريئ الله يرحم أبو الكابتن صالح سليم  خد قرار يخطيب والعب بفريق الشباب بناقص دورى السنه دى واكسب فريق جديد  اهلاوي وافتخر وبعشق النادى الأهلى
# مشكله الاهلى هى شخصيته دايما جمهوره عايز يبقى الاول ورقم   عشان كده ف تلاحم بطولات بتلحم بطوله ف بطوله وانت بتجيب صفقات جديده لسه مندمجتش ف الفريق ولا وقفت ع مستواها ف وقت صعب ومباريات هامه مبتقدرش تتهنى ب لاعب موسم كامل لازم أصابه
# Similarity between the two sentences: 85.96%
# -----------------------------------------------------------
#  الأهلى عايز راجل قوي ميخفش من اى حد يكون جريئ الله يرحم أبو الكابتن صالح سليم  خد قرار يخطيب والعب بفريق الشباب بناقص دورى السنه دى واكسب فريق جديد  اهلاوي وافتخر وبعشق النادى الأهلى
# وكابتن ياسر بيكمل عليك ومكنش عايز يادى الزمالك كورنر فداهم جون موتك وخلص عليك خالص
# Similarity between the two sentences: 85.27%
# -----------------------------------------------------------
#  الأهلى عايز راجل قوي ميخفش من اى حد يكون جريئ الله يرحم أبو الكابتن صالح سليم  خد قرار يخطيب والعب بفريق الشباب بناقص دورى السنه دى واكسب فريق جديد  اهلاوي وافتخر وبعشق النادى الأهلى
#  حقيقي بجد اللي خرب الاهلي جمهور السوشيال ميديا انا لا عايز موسيماني ولا سواريش انا عايز فايلر يرجع تاني
# Similarity between the two sentences: 88.71%
# -----------------------------------------------------------
#  الأهلى عايز راجل قوي ميخفش من اى حد يكون جريئ الله يرحم أبو الكابتن صالح سليم  خد قرار يخطيب والعب بفريق الشباب بناقص دورى السنه دى واكسب فريق جديد  اهلاوي وافتخر وبعشق النادى الأهلى
#    الزمالك سايبه براحته عايز تمشي قبل عقدك مايخلص اتفضل بس هتتغرم زي كهربا
# Similarity between the two sentences: 87.48%
# -----------------------------------------------------------
#  الأهلى عايز راجل قوي ميخفش من اى حد يكون جريئ الله يرحم أبو الكابتن صالح سليم  خد قرار يخطيب والعب بفريق الشباب بناقص دورى السنه دى واكسب فريق جديد  اهلاوي وافتخر وبعشق النادى الأهلى
#   اننا متعود اني باخد الدوري بغض النظر طبعا الموسم اللي فات كنت زي الزفت صح بس مبروك ليك انما انتوا كل ما اكلم حد زملكاوي اكلم بس الاقيه ما انا اخدت الدوري منك اللي هو ايوا يعني عايز اي مش فاهم ما نا واخدة قبلك طب انت يااحمد الزمالك معاه كام كاس مصر
# Similarity between the two sentences: 89.35%
# -----------------------------------------------------------
#  الأهلى عايز راجل قوي ميخفش من اى حد يكون جريئ الله يرحم أبو الكابتن صالح سليم  خد قرار يخطيب والعب بفريق الشباب بناقص دورى السنه دى واكسب فريق جديد  اهلاوي وافتخر وبعشق النادى الأهلى
# انا عايز اسئل الكابتن محمود الخطيب سؤالبكره هتقول ايه للاعيبه بتاعتك في التمرين؟؟؟ لاعب لا قدر وجودك في التمرين ولا معنى رساله ان رئيس النادي الاهلي يحضر تمرينه ويجتمع باللعيبه بتاعته ، في ايه تاني عندك تقولو ؟؟؟ الاجتماع اللي لازم يحصل هو اجتماعك مع نفسك وتحاسب نفسك
# Similarity between the two sentences: 85.85%
# -----------------------------------------------------------
#  الأهلى عايز راجل قوي ميخفش من اى حد يكون جريئ الله يرحم أبو الكابتن صالح سليم  خد قرار يخطيب والعب بفريق الشباب بناقص دورى السنه دى واكسب فريق جديد  اهلاوي وافتخر وبعشق النادى الأهلى
# الخطيب الجبان مش عايز يتعاقد مع بن شرقى وزيزو علشان المشاكل رغم ان اسود الزمالك خطفوا مننا ٤ لاعبات فى الطايرة ادارة جبانة ومحدش يقولى دعم دلوقتى النهاردة يوم الجلد والحساب
# Similarity between the two sentences: 85.32%
# -----------------------------------------------------------
#  الأهلى عايز راجل قوي ميخفش من اى حد يكون جريئ الله يرحم أبو الكابتن صالح سليم  خد قرار يخطيب والعب بفريق الشباب بناقص دورى السنه دى واكسب فريق جديد  اهلاوي وافتخر وبعشق النادى الأهلى
#  والله والله والله والله انو لو بيلعب مع الزمالك ما كان عمل كده بيعرض الكوره لوارى ياعم كل كورة عايز يرقص لعب فاضى هيوصل لجون اقسم بالله هو الا خلى الاهلى يهزم النهارده نص الشوط تانى  يقدر يعرض الكورة بيلعب مع المنافس
# Similarity between the two sentences: 86.14%
# -----------------------------------------------------------
#  الأهلى عايز راجل قوي ميخفش من اى حد يكون جريئ الله يرحم أبو الكابتن صالح سليم  خد قرار يخطيب والعب بفريق الشباب بناقص دورى السنه دى واكسب فريق جديد  اهلاوي وافتخر وبعشق النادى الأهلى
#  عايز تعالج الخطيب يرحل وياخد فى ايدة  لجنة التخطيط وعلى رأسهم محسن صالح عايز تعالج اعترف ان عندك لعيبة لا تصلح انها تلعب فى حوش مدرسة  افشة واحمد عبدالقادر  وطاهر ومحمد هانى  وغيرهم كتييييييير الفرقة عايزة تتفور  كلهاولما يبقى عندك لاعب فير  اسمه بن شرقي وخايف  تتعاقد معاه
# Similarity between the two sentences: 88.53%
# -----------------------------------------------------------
#  الأهلى عايز راجل قوي ميخفش من اى حد يكون جريئ الله يرحم أبو الكابتن صالح سليم  خد قرار يخطيب والعب بفريق الشباب بناقص دورى السنه دى واكسب فريق جديد  اهلاوي وافتخر وبعشق النادى الأهلى
# ادعم لاعيبة الاهلي وادعم مجلس الإدارة واللي يختلف مع مجلس الادارة مش اهلاوي ازاي تكون اهلاوي وتختلف مع الخطيب اللي لو كان محمود طاهر مكنو كان اتفشخ ازاي امشي مدرب جايب  افريقيا في نص الموسم وانت داخل علي اصعب فترة في الموسم ومحدش يقولي موسيماني اللي كان عايز يمشي
# Similarity between the two sentences: 90.71%
# -----------------------------------------------------------
#  الأهلى عايز راجل قوي ميخفش من اى حد يكون جريئ الله يرحم أبو الكابتن صالح سليم  خد قرار يخطيب والعب بفريق الشباب بناقص دورى السنه دى واكسب فريق جديد  اهلاوي وافتخر وبعشق النادى الأهلى
# هو الخطيب ده بشر زينا ولا هو حاجة تانية فوق النقدالخطيب هيدمر الأهليتركي مش سايبه وهو اللي جاب تركيحسام  المراهق بيلعب في الفريق زي ماهو عايزوبرضه هو اللي جاب حسام
# Similarity between the two sentences: 86.57%
# -----------------------------------------------------------
#  الأهلى عايز راجل قوي ميخفش من اى حد يكون جريئ الله يرحم أبو الكابتن صالح سليم  خد قرار يخطيب والعب بفريق الشباب بناقص دورى السنه دى واكسب فريق جديد  اهلاوي وافتخر وبعشق النادى الأهلى
# موسيماني فاضي ولو كلمته هيرجع ودا صعب عشان هتثبت فشلك وبن شرقي مستني وببلاش بس انت خايف من المشاكل وشوبير عايز ياخد الفرصه والشباب لو قولتلهم كملوا الدوري مش هتقول لا بس الكلام ده محتاج راجل
# Similarity between the two sentences: 88.20%
# -----------------------------------------------------------
#  الأهلى عايز راجل قوي ميخفش من اى حد يكون جريئ الله يرحم أبو الكابتن صالح سليم  خد قرار يخطيب والعب بفريق الشباب بناقص دورى السنه دى واكسب فريق جديد  اهلاوي وافتخر وبعشق النادى الأهلى
#  هو لعب بالمتاح ليه بيلعب بفرقه موقفه من القيد وحتي الشباب الي بيلعب بيهم في منهم مصابين علشان كده هو يستحق الاحترام هو عارف عايز ينزل يعمل ايه وعمل المطلوب منه الي هو المكسب للبطوله وبأداء محترم
# Similarity between the two sentences: 90.60%
# -----------------------------------------------------------
#  الأهلى عايز راجل قوي ميخفش من اى حد يكون جريئ الله يرحم أبو الكابتن صالح سليم  خد قرار يخطيب والعب بفريق الشباب بناقص دورى السنه دى واكسب فريق جديد  اهلاوي وافتخر وبعشق النادى الأهلى
# اللى عايز يفهم يفهم محمد محمود من لاعب برا القايمة خالص ليلعب مهاجم ازاى  ووليد سليمان اعتزل لية موجود هو ده وقت تكريم ليه مش كريم فؤاد بدل هانى وزياد بدل السوليه وعبد المنعم كان لازم يبداء ده فى كوارث حصلت فى الماتش كفاية اوى كدة على عبد الحفيظ وسامي
# Similarity between the two sentences: 85.66%
# -----------------------------------------------------------
#  الأهلى عايز راجل قوي ميخفش من اى حد يكون جريئ الله يرحم أبو الكابتن صالح سليم  خد قرار يخطيب والعب بفريق الشباب بناقص دورى السنه دى واكسب فريق جديد  اهلاوي وافتخر وبعشق النادى الأهلى
# عايز أشيد بإبن بلدي المنياوي أحمد أبو سيد زيزو وبكابتن سيد نيمار ع الأداء الجامد ده
# Similarity between the two sentences: 90.07%
# -----------------------------------------------------------
#  الأهلى عايز راجل قوي ميخفش من اى حد يكون جريئ الله يرحم أبو الكابتن صالح سليم  خد قرار يخطيب والعب بفريق الشباب بناقص دورى السنه دى واكسب فريق جديد  اهلاوي وافتخر وبعشق النادى الأهلى
# الزمالك خد من الاهلى الغيره والخوف على اسم النادى وجمع البطولات وساب للاهلى الشعارات بمساعده جماهيره افيقوا يرحمكم الله بلاش فلسفه المكن مستهلك خط الانتاج وقف المصنع عايز مكن جديد واسطى محترم يارب نفهم تعبنا من الكلام
# Similarity between the two sentences: 88.41%
# -----------------------------------------------------------
#  الأهلى عايز راجل قوي ميخفش من اى حد يكون جريئ الله يرحم أبو الكابتن صالح سليم  خد قرار يخطيب والعب بفريق الشباب بناقص دورى السنه دى واكسب فريق جديد  اهلاوي وافتخر وبعشق النادى الأهلى
# بصراحه انا مش عايز علاء عبدالصادق يشتغل او يمسك حاجه في الأهلي
# Similarity between the two sentences: 87.64%
# -----------------------------------------------------------
#  الأهلى عايز راجل قوي ميخفش من اى حد يكون جريئ الله يرحم أبو الكابتن صالح سليم  خد قرار يخطيب والعب بفريق الشباب بناقص دورى السنه دى واكسب فريق جديد  اهلاوي وافتخر وبعشق النادى الأهلى
# إدارة بقت طريه قناة إعلامية ماشية بالأوامر العليا ولا تعبر عن الجماهير ولا طموحها لاعيبة منهم لا يصلحوا لارتداء التيشرت مدرب لا يبشر بآي خير جمهور ميديا منقسم وكله عايز ياخد الللقطة رجعولنا الأهلي بتاعنا
# Similarity between the two sentences: 85.73%
# -----------------------------------------------------------
#  الأهلى عايز راجل قوي ميخفش من اى حد يكون جريئ الله يرحم أبو الكابتن صالح سليم  خد قرار يخطيب والعب بفريق الشباب بناقص دورى السنه دى واكسب فريق جديد  اهلاوي وافتخر وبعشق النادى الأهلى
#  زمان كنا بنقول للزملكاويه انتوا فريق كويس بس محتاجين اداره زى الاهلى اداره دلوقت باقول للاعبى الاهلى انتوا محتاجين واحد زى مرتضى يعلمكم الادب اداره متخبطه مرتعشه لاعيبه تايهه مش عارفه قيمة التيشيرتشناوى عايز يقعد دكه وتتسحب منه الشاره عشان مايستحقهاش
# Similarity between the two sentences: 90.20%
# -----------------------------------------------------------
#  الأهلى عايز راجل قوي ميخفش من اى حد يكون جريئ الله يرحم أبو الكابتن صالح سليم  خد قرار يخطيب والعب بفريق الشباب بناقص دورى السنه دى واكسب فريق جديد  اهلاوي وافتخر وبعشق النادى الأهلى

# -----------------------------------------------------------
#  الأهلى عايز راجل قوي ميخفش من اى حد يكون جريئ الله يرحم أبو الكابتن صالح سليم  خد قرار يخطيب والعب بفريق الشباب بناقص دورى السنه دى واكسب فريق جديد  اهلاوي وافتخر وبعشق النادى الأهلى
#  مساء الانوار يا كابتين مدحتانا شايف ان رجل المباراه هو فيريرا لأنه ادار المباراه زي ما هو عايز يستحق بالفعل لقب البروفيسور
# Similarity between the two sentences: 86.85%
# -----------------------------------------------------------
#  الأهلى عايز راجل قوي ميخفش من اى حد يكون جريئ الله يرحم أبو الكابتن صالح سليم  خد قرار يخطيب والعب بفريق الشباب بناقص دورى السنه دى واكسب فريق جديد  اهلاوي وافتخر وبعشق النادى الأهلى
# جدي فيريا لو عايز حد يرصلوا حجر شيشه يندهلي يا جماعه الزمالك
# Similarity between the two sentences: 87.12%
# -----------------------------------------------------------
#  الأهلى عايز راجل قوي ميخفش من اى حد يكون جريئ الله يرحم أبو الكابتن صالح سليم  خد قرار يخطيب والعب بفريق الشباب بناقص دورى السنه دى واكسب فريق جديد  اهلاوي وافتخر وبعشق النادى الأهلى
#  لا انا عايز الناس تجمد وتنشف كده احنا داخلين علي حقبة اسوء من حقبة لاسارتي سواريش ده علي الابيض لا بيعرف يحط خطة ولا يختار تشكيل ولا بيعرف يدخل بتعديلات أثناء سير اللقاء يعني داخلين علي سواد وموسم صغري هيكون الاول في تاريخ النادي
# Similarity between the two sentences: 85.04%
# -----------------------------------------------------------
#  الأهلى عايز راجل قوي ميخفش من اى حد يكون جريئ الله يرحم أبو الكابتن صالح سليم  خد قرار يخطيب والعب بفريق الشباب بناقص دورى السنه دى واكسب فريق جديد  اهلاوي وافتخر وبعشق النادى الأهلى
#  ماهو نفس الشيخ اللي كان عايز موسيماني يمشي باي شكل اوسخ حاجه ب تحصل ف الاهلي ان اللي منه هو اللي بيدمره للاسف ومجلس الاداره ماشي وراهم وورا السوشيال زفت حسبي الله ونعم الوكيل
# Similarity between the two sentences: 85.93%
# -----------------------------------------------------------
#  الأهلى عايز راجل قوي ميخفش من اى حد يكون جريئ الله يرحم أبو الكابتن صالح سليم  خد قرار يخطيب والعب بفريق الشباب بناقص دورى السنه دى واكسب فريق جديد  اهلاوي وافتخر وبعشق النادى الأهلى
# شغل لاسارتي بس علي تقيل كُتر كلام علي الفاضي عايز يكسب الجمهور بأي طريقة وخلاص
# Similarity between the two sentences: 85.17%
# -----------------------------------------------------------
#  الأهلى عايز راجل قوي ميخفش من اى حد يكون جريئ الله يرحم أبو الكابتن صالح سليم  خد قرار يخطيب والعب بفريق الشباب بناقص دورى السنه دى واكسب فريق جديد  اهلاوي وافتخر وبعشق النادى الأهلى
#  كابتن بيبو عايز حد يقعد معاه ويفكرو انه رئيس النادى الاهلى مش نادى درجه تانيه
# Similarity between the two sentences: 88.62%
# -----------------------------------------------------------
#  الأهلى عايز راجل قوي ميخفش من اى حد يكون جريئ الله يرحم أبو الكابتن صالح سليم  خد قرار يخطيب والعب بفريق الشباب بناقص دورى السنه دى واكسب فريق جديد  اهلاوي وافتخر وبعشق النادى الأهلى
#  طب اسمع طالما عايز تفهم الحوار كله عند حسام غالي ساعه م رجع الاداره موسماني مكنش عاجبه محمد هاني وشويه لاعيبه كان عايز يمشيهم حسام غالي رفض عشان هاني خطيب اخته شغل  تعريض كله وخلي لاعيبه الاهلي يقدموا شكوي فموسماني للخطيب ومن ساعتها محدش شايف حرفيا
# Similarity between the two sentences: 85.49%
# -----------------------------------------------------------
#  الأهلى عايز راجل قوي ميخفش من اى حد يكون جريئ الله يرحم أبو الكابتن صالح سليم  خد قرار يخطيب والعب بفريق الشباب بناقص دورى السنه دى واكسب فريق جديد  اهلاوي وافتخر وبعشق النادى الأهلى
#  بالظبط ده اللي بقوله انك مش جامد انت عندك مشاكل باينه جدا ومحتاج تجيب لعيبه حلوه ف الاماكن ديه لو عايز الفرقه تكمل بقوه و تبقى في التوب فورم وتفرح فعلا بفرقتك لاكن اي نفخ دلوقت حيوقعك مش حيفيدك واهو خدوا الاهلي مثال كان ضعيف وكسب النهائي فنفخوا اللعيبه من يومها مشفتش كوره
# Similarity between the two sentences: 88.35%
# -----------------------------------------------------------
#  الأهلى عايز راجل قوي ميخفش من اى حد يكون جريئ الله يرحم أبو الكابتن صالح سليم  خد قرار يخطيب والعب بفريق الشباب بناقص دورى السنه دى واكسب فريق جديد  اهلاوي وافتخر وبعشق النادى الأهلى
#  لا انا مش معاك لانه مش دايما وحش اكثر مباريته حلوه ولكن عايز مدرب كويس يشتغل عليه فى بعض النقاط إنما السوليه هو اللى منفوخ ع الفاضى
# Similarity between the two sentences: 86.14%
# -----------------------------------------------------------
#  الأهلى عايز راجل قوي ميخفش من اى حد يكون جريئ الله يرحم أبو الكابتن صالح سليم  خد قرار يخطيب والعب بفريق الشباب بناقص دورى السنه دى واكسب فريق جديد  اهلاوي وافتخر وبعشق النادى الأهلى
#  لو عايز تعرف مدي امتلاك لاعيبه الاهلي من أساسيات كرة القدم اتفرج لا وليد سليمان وهو بيستلم ويلف ويباصي دا اكبر دليل علي أن لاعبيه الجيل الحالي في الاهلي معظمهم مش بيعرفو يلعبون كوره من الاساس
# Similarity between the two sentences: 85.93%
# -----------------------------------------------------------
#  الأهلى عايز راجل قوي ميخفش من اى حد يكون جريئ الله يرحم أبو الكابتن صالح سليم  خد قرار يخطيب والعب بفريق الشباب بناقص دورى السنه دى واكسب فريق جديد  اهلاوي وافتخر وبعشق النادى الأهلى
# الي مش عايز الزمالك احنا مش عايزينه دا الي يغلط في الزمالك كلنا عارفينه ، وفاهمينه دا كداب حافظينه دا مهزوم والزمالك لما يقوم كل دول ملهمش لزوم
# Similarity between the two sentences: 85.12%
# -----------------------------------------------------------

# %%
pip install transformersl
# Out:
# Requirement already satisfied: transformers in /usr/local/lib/python3.10/dist-packages (4.35.2)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from transformers) (3.13.1)
# Requirement already satisfied: huggingface-hub<1.0,>=0.16.4 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.19.4)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (1.23.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from transformers) (23.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (6.0.1)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (2023.6.3)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from transformers) (2.31.0)
# Requirement already satisfied: tokenizers<0.19,>=0.14 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.15.0)
# Requirement already satisfied: safetensors>=0.3.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.4.0)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.10/dist-packages (from transformers) (4.66.1)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.16.4->transformers) (2023.6.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.16.4->transformers) (4.5.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2023.7.22)

# %%
# !pip install transformers arabert
# Out:
# Requirement already satisfied: transformers in /usr/local/lib/python3.10/dist-packages (4.35.2)
# Requirement already satisfied: arabert in /usr/local/lib/python3.10/dist-packages (1.0.1)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from transformers) (3.13.1)
# Requirement already satisfied: huggingface-hub<1.0,>=0.16.4 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.19.4)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (1.23.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from transformers) (23.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (6.0.1)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (2023.6.3)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from transformers) (2.31.0)
# Requirement already satisfied: tokenizers<0.19,>=0.14 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.15.0)
# Requirement already satisfied: safetensors>=0.3.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.4.0)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.10/dist-packages (from transformers) (4.66.1)
# Requirement already satisfied: PyArabic in /usr/local/lib/python3.10/dist-packages (from arabert) (0.6.15)
# Requirement already satisfied: farasapy in /usr/local/lib/python3.10/dist-packages (from arabert) (0.0.14)
# Requirement already satisfied: emoji==1.4.2 in /usr/local/lib/python3.10/dist-packages (from arabert) (1.4.2)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.16.4->transformers) (2023.6.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.16.4->transformers) (4.5.0)
# Requirement already satisfied: six>=1.14.0 in /usr/local/lib/python3.10/dist-packages (from PyArabic->arabert) (1.16.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2023.7.22)

# %%
from transformers import BertTokenizer, AutoModelForSeq2SeqLM, pipeline
from arabert.preprocess import ArabertPreprocessor

model_name = "malmarjeh/mbert2mbert-arabic-text-summarization"
preprocessor = ArabertPreprocessor(model_name="")

tokenizer = BertTokenizer.from_pretrained(model_name)
model = AutoModelForSeq2SeqLM.from_pretrained(model_name)
text2text_pipeline = pipeline("text2text-generation", model=model, tokenizer=tokenizer)

text = "شهدت مدينة طرابلس، مساء أمس الأربعاء، احتجاجات شعبية وأعمال شغب لليوم الثالث على التوالي، وذلك بسبب تردي الوضع المعيشي والاقتصادي. واندلعت مواجهات عنيفة وعمليات كر وفر ما بين الجيش اللبناني والمحتجين استمرت لساعات، إثر محاولة فتح الطرقات المقطوعة، ما أدى إلى إصابة العشرات من الطرفين."
text = preprocessor.preprocess(text)

result = text2text_pipeline(text, pad_token_id=tokenizer.eos_token_id, num_beams=3, repetition_penalty=3.0, max_length=200, length_penalty=1.0, no_repeat_ngram_size=3)[0]['generated_text']

print(result)
# Out:
# WARNING:root:Model provided is not in the accepted model list. Preprocessor will default to a base Arabic preprocessor
# The following encoder weights were not tied to the decoder ['bert/pooler']
# The following encoder weights were not tied to the decoder ['bert/pooler']
# The following encoder weights were not tied to the decoder ['bert/pooler']
# The following encoder weights were not tied to the decoder ['bert/pooler']
# Setting `pad_token_id` to `eos_token_id`:102 for open-end generation.
# احتجاجات في طرابلس على خلفية مواجهات عنيفة بين الجيش اللبناني والمحتجين

# %%
text = "شهدت مدينة طرابلس، مساء أمس الأربعاء، احتجاجات شعبية وأعمال شغب لليوم الثالث على التوالي، وذلك بسبب تردي الوضع المعيشي والاقتصادي. واندلعت مواجهات عنيفة وعمليات كر وفر ما بين الجيش اللبناني والمحتجين استمرت لساعات، إثر محاولة فتح الطرقات المقطوعة، ما أدى إلى إصابة العشرات من الطرفين."
text = preprocessor.preprocess(text)

result = text2text_pipeline(text, pad_token_id=tokenizer.eos_token_id, num_beams=3, repetition_penalty=3.0, max_length=30, length_penalty=1.0, no_repeat_ngram_size=3)[0]['generated_text']

print(result)
# Out:
# Setting `pad_token_id` to `eos_token_id`:102 for open-end generation.
# احتجاجات في طرابلس على خلفية مواجهات عنيفة بين الجيش اللبناني والمحتجين

# %%
text = "احتجاجات في طرابلس على خلفية مواجهات عنيفة بين الجيش اللبناني والمحتجين"
max_length_in_words = 50  # Replace with your desired maximum length in words

# Tokenize the text and get the number of tokens
tokenized_text = tokenizer.encode(text, add_special_tokens=True)
num_tokens = len(tokenized_text)

# Convert max_length_in_words to max_length_in_tokens
max_length_in_tokens = tokenizer.convert_words_to_tokens(max_length_in_words)

# Set max_length in the text2text_pipeline
result = text2text_pipeline(
    text,
    pad_token_id=tokenizer.eos_token_id,
    num_beams=3,
    repetition_penalty=3.0,
    max_length=max_length_in_tokens,
    length_penalty=1.0,
    no_repeat_ngram_size=3
)[0]['generated_text']
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-6-ff663ea1c2af> in <cell line: 9>()
#       7
#       8 # Convert max_length_in_words to max_length_in_tokens
# ----> 9 max_length_in_tokens = tokenizer.convert_words_to_tokens(max_length_in_words)
#      10
#      11 # Set max_length in the text2text_pipeline
#
# AttributeError: 'BertTokenizer' object has no attribute 'convert_words_to_tokens'

# %%
from transformers import AutoTokenizer, Text2TextGenerationPipeline

# Load the tokenizer
tokenizer = AutoTokenizer.from_pretrained("akhooli/gpt2-small-arabic")

# Load the text2text pipeline
text2text_pipeline = Text2TextGenerationPipeline(model="akhooli/gpt2-small-arabic", tokenizer=tokenizer)

# Your input text
# text = "Your input text here."

# Specify the maximum length in words
max_length_in_words = 50

# Generate text with max_length specified in words
result = text2text_pipeline(
    text,
    max_length=max_length_in_words,
    num_beams=3,
    repetition_penalty=3.0,
    length_penalty=1.0,
    no_repeat_ngram_size=3
)[0]['generated_text']
# Out:
# tokenizer_config.json:   0%|          | 0.00/30.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/666 [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/1.55M [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/1.21M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/120 [00:00<?, ?B/s]
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-7-d7eefdf590fb> in <cell line: 7>()
#       5
#       6 # Load the text2text pipeline
# ----> 7 text2text_pipeline = Text2TextGenerationPipeline(model="akhooli/gpt2-small-arabic", tokenizer=tokenizer)
#       8
#       9 # Your input text
#
# /usr/local/lib/python3.10/dist-packages/transformers/pipelines/text2text_generation.py in __init__(self, *args, **kwargs)
#      65
#      66     def __init__(self, *args, **kwargs):
# ---> 67         super().__init__(*args, **kwargs)
#      68
#      69         self.check_model_type(
#
# /usr/local/lib/python3.10/dist-packages/transformers/pipelines/base.py in __init__(self, model, tokenizer, feature_extractor, image_processor, modelcard, framework, task, args_parser, device, torch_dtype, binary_output, **kwargs)
#     774     ):
#     775         if framework is None:
# --> 776             framework, model = infer_framework_load_model(model, config=model.config)
#     777
#     778         self.task = task
#
# AttributeError: 'str' object has no attribute 'config'

# %%
from transformers import AutoTokenizer, AutoModelForCausalLM, Text2TextGenerationPipeline

# Load the tokenizer and model
tokenizer = AutoTokenizer.from_pretrained("akhooli/gpt2-small-arabic")
model = AutoModelForCausalLM.from_pretrained("akhooli/gpt2-small-arabic")

# Create the text2text pipeline
text2text_pipeline = Text2TextGenerationPipeline(model=model, tokenizer=tokenizer)

# Your input text
# text = "Your input text here."

# Specify the maximum length in words
max_length_in_words = 50

# Generate text with max_length specified in words
result = text2text_pipeline(
    text,
    max_length=max_length_in_words,
    num_beams=3,
    repetition_penalty=3.0,
    length_penalty=1.0,
    no_repeat_ngram_size=3
)[0]['generated_text']

print(result)
# Out:
# The model 'GPT2LMHeadModel' is not supported for . Supported models are ['BartForConditionalGeneration', 'BigBirdPegasusForConditionalGeneration', 'BlenderbotForConditionalGeneration', 'BlenderbotSmallForConditionalGeneration', 'EncoderDecoderModel', 'FSMTForConditionalGeneration', 'GPTSanJapaneseForConditionalGeneration', 'LEDForConditionalGeneration', 'LongT5ForConditionalGeneration', 'M2M100ForConditionalGeneration', 'MarianMTModel', 'MBartForConditionalGeneration', 'MT5ForConditionalGeneration', 'MvpForConditionalGeneration', 'NllbMoeForConditionalGeneration', 'PegasusForConditionalGeneration', 'PegasusXForConditionalGeneration', 'PLBartForConditionalGeneration', 'ProphetNetForConditionalGeneration', 'SeamlessM4TForTextToText', 'SwitchTransformersForConditionalGeneration', 'T5ForConditionalGeneration', 'UMT5ForConditionalGeneration', 'XLMProphetNetForConditionalGeneration'].
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# احتجاجات في طرابلس على خلفية مواجهات عنيفة بين الجيش اللبناني والمحتجين. وفي اليوم التالي، اندلعت اشتباكات مع القوات الموالية للحكومة

# %%
# Create the text2text pipeline
text2text_pipeline = Text2TextGenerationPipeline(model=model, tokenizer=tokenizer)

# Your input text
# text = "Your input text here."

# Specify the maximum length in words
max_length_in_words = 20
# Generate text with max_length specified in words
result = text2text_pipeline(
    text,
    max_length=max_length_in_words,
    num_beams=3,
    repetition_penalty=3.0,
    length_penalty=1.0,
    no_repeat_ngram_size=3
)[0]['generated_text']

print(result)
# Out:
# The model 'GPT2LMHeadModel' is not supported for . Supported models are ['BartForConditionalGeneration', 'BigBirdPegasusForConditionalGeneration', 'BlenderbotForConditionalGeneration', 'BlenderbotSmallForConditionalGeneration', 'EncoderDecoderModel', 'FSMTForConditionalGeneration', 'GPTSanJapaneseForConditionalGeneration', 'LEDForConditionalGeneration', 'LongT5ForConditionalGeneration', 'M2M100ForConditionalGeneration', 'MarianMTModel', 'MBartForConditionalGeneration', 'MT5ForConditionalGeneration', 'MvpForConditionalGeneration', 'NllbMoeForConditionalGeneration', 'PegasusForConditionalGeneration', 'PegasusXForConditionalGeneration', 'PLBartForConditionalGeneration', 'ProphetNetForConditionalGeneration', 'SeamlessM4TForTextToText', 'SwitchTransformersForConditionalGeneration', 'T5ForConditionalGeneration', 'UMT5ForConditionalGeneration', 'XLMProphetNetForConditionalGeneration'].
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# احتجاجات في طرابلس على خلفية مواجهات عنيفة بين الجيش اللبناني والمحتجين. وفي اليوم التالي، اندلعت
